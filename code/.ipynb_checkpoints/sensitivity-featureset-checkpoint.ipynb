# %% [markdown]
# ### Load data set with features

# %%
from create_df import read_df
df, dfc, all_homes, appliance_min, national_average = read_df()
# Out:
# Vendor:  Continuum Analytics, Inc.
# Package: mkl
# Message: trial mode expires in 30 days

# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run all_functions.py

# %%
run features.py

# %%
import json

# %%
len(feature_map['15 min AMI']), len(feature_map['All']), len(feature_map['Monthly+Static']), len(feature_map['Monthly'])
# Out:
# (40, 43, 18, 15)

# %%
feature_map.keys()
# Out:
# ['Monthly', 'All', '15 min AMI', 'Static', 'Monthly+Static']

# %% [markdown]
# #### First round of CV, finding optimal features maximising median accuracy

# %%
out_median, optimal_dict_median = find_optimal_features(df, dfc, all_homes, appliance_min, national_average, 
                                                        ["hvac","light","fridge","dr","wm","dw"],
                                                        {"Static":feature_map["Static"],
                                                        'Monthly':feature_map['Monthly']},
                          NUM_NEIGHBOURS_MAX=7, F_length_max=7, metric="median",
                          train_outlier=True, test_outlier=False, outlier_features=None, outlier_fraction=0.1,
                     print_steps=True)
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_5 -> feature_subset: ['aggregate_5']. Accuracy: 81.5093101239
# include: aggregate_7 -> feature_subset: ['aggregate_5', 'aggregate_7']. Accuracy: 83.3832876158
# include: aggregate_9 -> feature_subset: ['aggregate_5', 'aggregate_7', 'aggregate_9']. Accuracy: 84.3130341951
# include: aggregate_12 -> feature_subset: ['aggregate_5', 'aggregate_7', 'aggregate_9', 'aggregate_12']. Accuracy: 84.3594715233
# include: aggregate_2 -> feature_subset: ['aggregate_5', 'aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_2']. Accuracy: 84.9079572132
# include: aggregate_8 -> feature_subset: ['aggregate_5', 'aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_2', 'aggregate_8']. Accuracy: 84.8096670697
# include: aggregate_11 -> feature_subset: ['aggregate_5', 'aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_2', 'aggregate_8', 'aggregate_11']. Accuracy: 85.1911889682
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 83.590349584
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_9']. Accuracy: 84.7745165456
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_9', 'aggregate_12']. Accuracy: 84.5531548001
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_5']. Accuracy: 86.2979155836
# include: aggregate_8 -> feature_subset: ['aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_5', 'aggregate_8']. Accuracy: 86.0545964372
# include: aggregate_1 -> feature_subset: ['aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_5', 'aggregate_8', 'aggregate_1']. Accuracy: 86.1665150504
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_9', 'aggregate_12', 'aggregate_5', 'aggregate_8', 'aggregate_1', 'aggregate_6']. Accuracy: 86.153847323
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 86.1845369235
# include: aggregate_4 -> feature_subset: ['aggregate_7', 'aggregate_4']. Accuracy: 86.348680267
# include: aggregate_3 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_3']. Accuracy: 85.6128551971
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_3', 'aggregate_5']. Accuracy: 86.472706632
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_3', 'aggregate_5', 'aggregate_2']. Accuracy: 86.5405456883
# include: ratio_min_max -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_3', 'aggregate_5', 'aggregate_2', 'ratio_min_max']. Accuracy: 86.1039533368
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_3', 'aggregate_5', 'aggregate_2', 'ratio_min_max', 'aggregate_9']. Accuracy: 86.6687264819
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 85.1778832019
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_2']. Accuracy: 86.5739332456
# include: aggregate_3 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3']. Accuracy: 86.3642414969
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_5']. Accuracy: 86.3846101353
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_5', 'aggregate_10']. Accuracy: 86.2329557547
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_5', 'aggregate_10', 'aggregate_12']. Accuracy: 86.3080023195
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_5', 'aggregate_10', 'aggregate_12', 'difference_min_max']. Accuracy: 86.4094552797
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 85.1699458651
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_12']. Accuracy: 86.3033493532
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_5']. Accuracy: 86.5078258303
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_5', 'aggregate_11']. Accuracy: 86.3452792936
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_5', 'aggregate_11', 'difference_min_max']. Accuracy: 86.897344544
# include: aggregate_3 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_5', 'aggregate_11', 'difference_min_max', 'aggregate_3']. Accuracy: 86.786910736
# include: aggregate_1 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_5', 'aggregate_11', 'difference_min_max', 'aggregate_3', 'aggregate_1']. Accuracy: 86.2938935945
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 84.7922354677
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_11']. Accuracy: 85.1807911519
# include: aggregate_4 -> feature_subset: ['aggregate_7', 'aggregate_11', 'aggregate_4']. Accuracy: 86.3333500615
# include: aggregate_1 -> feature_subset: ['aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_1']. Accuracy: 85.2934056462
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_1', 'aggregate_5']. Accuracy: 85.6850007993
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_1', 'aggregate_5', 'difference_min_max']. Accuracy: 85.6818053738
# include: ratio_min_max -> feature_subset: ['aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_1', 'aggregate_5', 'difference_min_max', 'ratio_min_max']. Accuracy: 85.5333020096
# 5 ['aggregate_7', 'aggregate_12', 'aggregate_5', 'aggregate_11', 'difference_min_max'] 86.897344544
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 74.0346954317
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 70.4136681661
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 66.1146605558
# include: area -> feature_subset: ['area']. Accuracy: 79.4704898678
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 76.4700951386
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 76.619730956
# include: area -> feature_subset: ['area']. Accuracy: 79.6732452927
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 76.7133228
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 78.8778187438
# include: area -> feature_subset: ['area']. Accuracy: 78.1022679175
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 78.1239080897
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 76.6045893262
# include: area -> feature_subset: ['area']. Accuracy: 80.1315056846
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 77.7873240492
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 76.6251176131
# include: area -> feature_subset: ['area']. Accuracy: 79.8377892985
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 79.5034202475
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 77.2390023381
# 5 ['area'] 80.1315056846
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 38.0636799624
# include: aggregate_6 -> feature_subset: ['ratio_min_max', 'aggregate_6']. Accuracy: 40.1284882944
# include: ratio_difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_6', 'ratio_difference_min_max']. Accuracy: 42.0718379787
# include: difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_6', 'ratio_difference_min_max', 'difference_min_max']. Accuracy: 40.1284882944
# include: aggregate_5 -> feature_subset: ['ratio_min_max', 'aggregate_6', 'ratio_difference_min_max', 'difference_min_max', 'aggregate_5']. Accuracy: 38.9006509563
# include: aggregate_9 -> feature_subset: ['ratio_min_max', 'aggregate_6', 'ratio_difference_min_max', 'difference_min_max', 'aggregate_5', 'aggregate_9']. Accuracy: 35.6370718531
# include: aggregate_11 -> feature_subset: ['ratio_min_max', 'aggregate_6', 'ratio_difference_min_max', 'difference_min_max', 'aggregate_5', 'aggregate_9', 'aggregate_11']. Accuracy: 35.8160383526
# include: difference_min_max -> feature_subset: ['difference_min_max']. Accuracy: 42.5102730051
# include: aggregate_8 -> feature_subset: ['difference_min_max', 'aggregate_8']. Accuracy: 47.6730755207
# include: aggregate_4 -> feature_subset: ['difference_min_max', 'aggregate_8', 'aggregate_4']. Accuracy: 48.4539601162
# include: aggregate_2 -> feature_subset: ['difference_min_max', 'aggregate_8', 'aggregate_4', 'aggregate_2']. Accuracy: 46.6473618051
# include: aggregate_5 -> feature_subset: ['difference_min_max', 'aggregate_8', 'aggregate_4', 'aggregate_2', 'aggregate_5']. Accuracy: 45.9432362542
# include: aggregate_7 -> feature_subset: ['difference_min_max', 'aggregate_8', 'aggregate_4', 'aggregate_2', 'aggregate_5', 'aggregate_7']. Accuracy: 44.4493944023
# include: ratio_min_max -> feature_subset: ['difference_min_max', 'aggregate_8', 'aggregate_4', 'aggregate_2', 'aggregate_5', 'aggregate_7', 'ratio_min_max']. Accuracy: 46.6097629681
# include: difference_min_max -> feature_subset: ['difference_min_max']. Accuracy: 44.4305064251
# include: aggregate_6 -> feature_subset: ['difference_min_max', 'aggregate_6']. Accuracy: 45.2077111704
# include: aggregate_2 -> feature_subset: ['difference_min_max', 'aggregate_6', 'aggregate_2']. Accuracy: 46.2474106256
# include: aggregate_10 -> feature_subset: ['difference_min_max', 'aggregate_6', 'aggregate_2', 'aggregate_10']. Accuracy: 45.6589800369
# include: aggregate_7 -> feature_subset: ['difference_min_max', 'aggregate_6', 'aggregate_2', 'aggregate_10', 'aggregate_7']. Accuracy: 46.0463097855
# include: aggregate_4 -> feature_subset: ['difference_min_max', 'aggregate_6', 'aggregate_2', 'aggregate_10', 'aggregate_7', 'aggregate_4']. Accuracy: 46.5859426794
# include: aggregate_8 -> feature_subset: ['difference_min_max', 'aggregate_6', 'aggregate_2', 'aggregate_10', 'aggregate_7', 'aggregate_4', 'aggregate_8']. Accuracy: 45.1363971953
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 45.5657343376
# include: aggregate_10 -> feature_subset: ['aggregate_1', 'aggregate_10']. Accuracy: 46.7217734064
# include: aggregate_2 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2']. Accuracy: 45.1005819551
# include: aggregate_5 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_5']. Accuracy: 45.2008168284
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_5', 'aggregate_11']. Accuracy: 43.5703814814
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_4']. Accuracy: 43.8660311007
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_4', 'aggregate_3']. Accuracy: 42.7687464408
# include: aggregate_2 -> feature_subset: ['aggregate_2']. Accuracy: 45.2590898579
# include: aggregate_5 -> feature_subset: ['aggregate_2', 'aggregate_5']. Accuracy: 45.2397834129
# include: aggregate_11 -> feature_subset: ['aggregate_2', 'aggregate_5', 'aggregate_11']. Accuracy: 45.0185131479
# include: aggregate_3 -> feature_subset: ['aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_3']. Accuracy: 45.1123653453
# include: aggregate_10 -> feature_subset: ['aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_3', 'aggregate_10']. Accuracy: 45.2383153461
# include: ratio_min_max -> feature_subset: ['aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_3', 'aggregate_10', 'ratio_min_max']. Accuracy: 43.4429813329
# include: aggregate_9 -> feature_subset: ['aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_3', 'aggregate_10', 'ratio_min_max', 'aggregate_9']. Accuracy: 44.7288008018
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 46.0799610898
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_11']. Accuracy: 45.6725453637
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_11', 'aggregate_4']. Accuracy: 45.4321255461
# include: aggregate_2 -> feature_subset: ['aggregate_1', 'aggregate_11', 'aggregate_4', 'aggregate_2']. Accuracy: 45.3301384386
# include: aggregate_12 -> feature_subset: ['aggregate_1', 'aggregate_11', 'aggregate_4', 'aggregate_2', 'aggregate_12']. Accuracy: 45.635911369
# include: aggregate_6 -> feature_subset: ['aggregate_1', 'aggregate_11', 'aggregate_4', 'aggregate_2', 'aggregate_12', 'aggregate_6']. Accuracy: 45.1188547774
# include: aggregate_10 -> feature_subset: ['aggregate_1', 'aggregate_11', 'aggregate_4', 'aggregate_2', 'aggregate_12', 'aggregate_6', 'aggregate_10']. Accuracy: 45.125790505
# 2 ['difference_min_max', 'aggregate_8', 'aggregate_4'] 48.4539601162
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 39.791072951
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 38.3552352578
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 39.9320182568
# include: area -> feature_subset: ['area']. Accuracy: 50.1520977049
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 42.724867838
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 34.3520207072
# include: area -> feature_subset: ['area']. Accuracy: 50.2927499654
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 49.3076744771
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 37.9278296591
# include: area -> feature_subset: ['area']. Accuracy: 48.3942589166
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 43.2407520105
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 40.8975262231
# include: area -> feature_subset: ['area']. Accuracy: 53.3342896679
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 43.986568567
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 34.9883182382
# include: area -> feature_subset: ['area']. Accuracy: 52.7797930665
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 46.4951528211
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 34.64646002
# 5 ['area'] 53.3342896679
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 82.9378147592
# include: aggregate_12 -> feature_subset: ['aggregate_1', 'aggregate_12']. Accuracy: 83.9147983659
# include: ratio_min_max -> feature_subset: ['aggregate_1', 'aggregate_12', 'ratio_min_max']. Accuracy: 80.6343153556
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'aggregate_12', 'ratio_min_max', 'aggregate_3']. Accuracy: 80.7009842552
# include: ratio_difference_min_max -> feature_subset: ['aggregate_1', 'aggregate_12', 'ratio_min_max', 'aggregate_3', 'ratio_difference_min_max']. Accuracy: 82.171215958
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_12', 'ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4']. Accuracy: 82.171215958
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_12', 'ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_11']. Accuracy: 80.8538370859
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 79.3343407098
# include: ratio_min_max -> feature_subset: ['aggregate_1', 'ratio_min_max']. Accuracy: 83.0459774938
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'ratio_min_max', 'aggregate_4']. Accuracy: 83.9810008801
# include: aggregate_2 -> feature_subset: ['aggregate_1', 'ratio_min_max', 'aggregate_4', 'aggregate_2']. Accuracy: 84.4191305511
# include: ratio_difference_min_max -> feature_subset: ['aggregate_1', 'ratio_min_max', 'aggregate_4', 'aggregate_2', 'ratio_difference_min_max']. Accuracy: 84.4191305511
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'ratio_min_max', 'aggregate_4', 'aggregate_2', 'ratio_difference_min_max', 'aggregate_3']. Accuracy: 82.9757086146
# include: aggregate_7 -> feature_subset: ['aggregate_1', 'ratio_min_max', 'aggregate_4', 'aggregate_2', 'ratio_difference_min_max', 'aggregate_3', 'aggregate_7']. Accuracy: 82.516335211
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 81.6090661864
# include: aggregate_3 -> feature_subset: ['ratio_min_max', 'aggregate_3']. Accuracy: 83.867019408
# include: ratio_difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max']. Accuracy: 85.6363783058
# include: aggregate_4 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4']. Accuracy: 85.3608614829
# include: aggregate_7 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_7']. Accuracy: 83.9316473367
# include: aggregate_1 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_7', 'aggregate_1']. Accuracy: 83.9316473367
# include: aggregate_9 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_7', 'aggregate_1', 'aggregate_9']. Accuracy: 84.7462460751
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 81.4899142612
# include: aggregate_3 -> feature_subset: ['ratio_min_max', 'aggregate_3']. Accuracy: 84.151387497
# include: ratio_difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max']. Accuracy: 84.1520296166
# include: aggregate_1 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_1']. Accuracy: 83.3150292264
# include: aggregate_7 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_1', 'aggregate_7']. Accuracy: 83.2475188759
# include: aggregate_2 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_1', 'aggregate_7', 'aggregate_2']. Accuracy: 82.3755450519
# include: aggregate_4 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_1', 'aggregate_7', 'aggregate_2', 'aggregate_4']. Accuracy: 81.8437590106
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 78.7476757851
# include: aggregate_3 -> feature_subset: ['aggregate_7', 'aggregate_3']. Accuracy: 79.6318819729
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_3', 'aggregate_6']. Accuracy: 80.1255333787
# include: ratio_min_max -> feature_subset: ['aggregate_7', 'aggregate_3', 'aggregate_6', 'ratio_min_max']. Accuracy: 79.0701540221
# include: aggregate_1 -> feature_subset: ['aggregate_7', 'aggregate_3', 'aggregate_6', 'ratio_min_max', 'aggregate_1']. Accuracy: 79.0701540221
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_3', 'aggregate_6', 'ratio_min_max', 'aggregate_1', 'aggregate_11']. Accuracy: 79.585974317
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_3', 'aggregate_6', 'ratio_min_max', 'aggregate_1', 'aggregate_11', 'aggregate_2']. Accuracy: 79.585974317
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 77.4357025345
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_5']. Accuracy: 77.9080590757
# include: aggregate_10 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_10']. Accuracy: 78.3539426327
# include: aggregate_2 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_10', 'aggregate_2']. Accuracy: 78.4190395689
# include: aggregate_11 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_10', 'aggregate_2', 'aggregate_11']. Accuracy: 78.1148104706
# include: ratio_min_max -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'ratio_min_max']. Accuracy: 77.7896211985
# include: aggregate_7 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'ratio_min_max', 'aggregate_7']. Accuracy: 78.291804783
# 3 ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max'] 85.6363783058
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 74.4464570276
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 76.3219093772
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 82.4899472849
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 78.580899739
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 76.0772711656
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 78.9916605351
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 80.5172158888
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 78.5918928297
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 77.3076450016
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 81.4673425702
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 80.660010183
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 74.6598219702
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 81.1675942409
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 77.8546114844
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 74.8443021604
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 81.3194040411
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 79.0399987163
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 76.7734557525
# 1 ['total_occupants', 'area', 'num_rooms'] 82.4899472849
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 37.0094259058
# include: aggregate_8 -> feature_subset: ['aggregate_1', 'aggregate_8']. Accuracy: 34.8198607273
# include: aggregate_9 -> feature_subset: ['aggregate_1', 'aggregate_8', 'aggregate_9']. Accuracy: 41.6366576897
# include: difference_min_max -> feature_subset: ['aggregate_1', 'aggregate_8', 'aggregate_9', 'difference_min_max']. Accuracy: 45.1830602965
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'aggregate_8', 'aggregate_9', 'difference_min_max', 'aggregate_3']. Accuracy: 44.7249053776
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_8', 'aggregate_9', 'difference_min_max', 'aggregate_3', 'aggregate_11']. Accuracy: 46.0871302008
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_8', 'aggregate_9', 'difference_min_max', 'aggregate_3', 'aggregate_11', 'aggregate_4']. Accuracy: 47.1697006661
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 43.5352733027
# include: aggregate_1 -> feature_subset: ['aggregate_12', 'aggregate_1']. Accuracy: 44.8034579078
# include: aggregate_10 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_10']. Accuracy: 42.6318092774
# include: aggregate_11 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_10', 'aggregate_11']. Accuracy: 39.1656267184
# include: aggregate_8 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_10', 'aggregate_11', 'aggregate_8']. Accuracy: 39.0921850331
# include: aggregate_9 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_10', 'aggregate_11', 'aggregate_8', 'aggregate_9']. Accuracy: 41.7971224055
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_10', 'aggregate_11', 'aggregate_8', 'aggregate_9', 'aggregate_4']. Accuracy: 41.600731549
# include: aggregate_5 -> feature_subset: ['aggregate_5']. Accuracy: 45.5508328602
# include: aggregate_1 -> feature_subset: ['aggregate_5', 'aggregate_1']. Accuracy: 47.0192969853
# include: aggregate_2 -> feature_subset: ['aggregate_5', 'aggregate_1', 'aggregate_2']. Accuracy: 47.1247971027
# include: aggregate_3 -> feature_subset: ['aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_3']. Accuracy: 43.0287558607
# include: ratio_min_max -> feature_subset: ['aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_3', 'ratio_min_max']. Accuracy: 44.0373507408
# include: aggregate_4 -> feature_subset: ['aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_3', 'ratio_min_max', 'aggregate_4']. Accuracy: 44.2864315415
# include: aggregate_8 -> feature_subset: ['aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_3', 'ratio_min_max', 'aggregate_4', 'aggregate_8']. Accuracy: 41.6610719744
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 47.9624447241
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_12']. Accuracy: 45.0301526463
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7']. Accuracy: 44.6657925193
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11']. Accuracy: 45.4959845846
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4']. Accuracy: 44.1805324982
# include: aggregate_5 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_5']. Accuracy: 42.9388804479
# include: aggregate_9 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_5', 'aggregate_9']. Accuracy: 42.2981427955
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 48.7968483158
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_11']. Accuracy: 46.093782763
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_12']. Accuracy: 46.4808179363
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_12', 'aggregate_2']. Accuracy: 47.4146831486
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_12', 'aggregate_2', 'aggregate_1']. Accuracy: 47.4753576727
# include: aggregate_5 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_12', 'aggregate_2', 'aggregate_1', 'aggregate_5']. Accuracy: 46.5836988877
# include: aggregate_3 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_12', 'aggregate_2', 'aggregate_1', 'aggregate_5', 'aggregate_3']. Accuracy: 45.4456676244
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 49.4103530807
# include: aggregate_6 -> feature_subset: ['aggregate_10', 'aggregate_6']. Accuracy: 48.8265302233
# include: aggregate_9 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_9']. Accuracy: 48.1570437123
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_9', 'aggregate_4']. Accuracy: 47.1031647106
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_9', 'aggregate_4', 'aggregate_12']. Accuracy: 46.1716806851
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_9', 'aggregate_4', 'aggregate_12', 'aggregate_1']. Accuracy: 44.8750420291
# include: aggregate_3 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_9', 'aggregate_4', 'aggregate_12', 'aggregate_1', 'aggregate_3']. Accuracy: 44.9986401776
# 6 ['aggregate_10'] 49.4103530807
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 27.0886642839
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 29.2538862071
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 29.249706142
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 43.3579827473
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 42.9404263763
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 34.4713529191
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 48.0852732004
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 44.1626488603
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 41.6117148586
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 45.4985308855
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 47.7264583298
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 44.1682619167
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 47.5262886216
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 47.0023996799
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 45.7258336736
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 47.8826368805
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 45.9131119272
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 43.8863363785
# 3 ['total_occupants'] 48.0852732004
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 67.5527072411
# include: aggregate_10 -> feature_subset: ['aggregate_11', 'aggregate_10']. Accuracy: 70.9106734562
# include: aggregate_2 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2']. Accuracy: 70.5367437416
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1']. Accuracy: 69.0599791469
# include: difference_min_max -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max']. Accuracy: 71.2453545266
# include: aggregate_12 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max', 'aggregate_12']. Accuracy: 68.0736538622
# include: ratio_min_max -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max', 'aggregate_12', 'ratio_min_max']. Accuracy: 67.9864298812
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 68.014894532
# include: aggregate_4 -> feature_subset: ['aggregate_11', 'aggregate_4']. Accuracy: 68.8973798708
# include: aggregate_9 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_9']. Accuracy: 68.5640740033
# include: aggregate_7 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_9', 'aggregate_7']. Accuracy: 68.2226134874
# include: aggregate_3 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_9', 'aggregate_7', 'aggregate_3']. Accuracy: 68.8286508404
# include: aggregate_12 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_9', 'aggregate_7', 'aggregate_3', 'aggregate_12']. Accuracy: 67.9011019545
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_9', 'aggregate_7', 'aggregate_3', 'aggregate_12', 'aggregate_1']. Accuracy: 67.9011019545
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 67.271490759
# include: aggregate_7 -> feature_subset: ['aggregate_11', 'aggregate_7']. Accuracy: 70.3294822033
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_7', 'aggregate_1']. Accuracy: 71.5174330837
# include: aggregate_10 -> feature_subset: ['aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_10']. Accuracy: 70.9674028889
# include: aggregate_5 -> feature_subset: ['aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_5']. Accuracy: 69.3106372122
# include: aggregate_2 -> feature_subset: ['aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_5', 'aggregate_2']. Accuracy: 68.9270724644
# include: aggregate_4 -> feature_subset: ['aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_5', 'aggregate_2', 'aggregate_4']. Accuracy: 68.9270724644
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 68.5375815194
# include: aggregate_8 -> feature_subset: ['aggregate_7', 'aggregate_8']. Accuracy: 68.1241403057
# include: aggregate_4 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_4']. Accuracy: 67.9223941768
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_4', 'aggregate_9']. Accuracy: 68.184133299
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_4', 'aggregate_9', 'aggregate_6']. Accuracy: 67.4697166225
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_4', 'aggregate_9', 'aggregate_6', 'aggregate_11']. Accuracy: 68.1842900229
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_4', 'aggregate_9', 'aggregate_6', 'aggregate_11', 'aggregate_10']. Accuracy: 67.9271020104
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 66.6963748724
# include: aggregate_9 -> feature_subset: ['aggregate_11', 'aggregate_9']. Accuracy: 67.1708850604
# include: aggregate_7 -> feature_subset: ['aggregate_11', 'aggregate_9', 'aggregate_7']. Accuracy: 67.4969523004
# include: aggregate_8 -> feature_subset: ['aggregate_11', 'aggregate_9', 'aggregate_7', 'aggregate_8']. Accuracy: 69.0682914943
# include: aggregate_6 -> feature_subset: ['aggregate_11', 'aggregate_9', 'aggregate_7', 'aggregate_8', 'aggregate_6']. Accuracy: 68.0495698951
# include: aggregate_3 -> feature_subset: ['aggregate_11', 'aggregate_9', 'aggregate_7', 'aggregate_8', 'aggregate_6', 'aggregate_3']. Accuracy: 67.9326842757
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_9', 'aggregate_7', 'aggregate_8', 'aggregate_6', 'aggregate_3', 'aggregate_1']. Accuracy: 67.9787746996
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 68.2582367347
# include: aggregate_7 -> feature_subset: ['aggregate_8', 'aggregate_7']. Accuracy: 68.6709988222
# include: aggregate_1 -> feature_subset: ['aggregate_8', 'aggregate_7', 'aggregate_1']. Accuracy: 68.7576623138
# include: difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_7', 'aggregate_1', 'difference_min_max']. Accuracy: 68.3117335914
# include: aggregate_10 -> feature_subset: ['aggregate_8', 'aggregate_7', 'aggregate_1', 'difference_min_max', 'aggregate_10']. Accuracy: 68.5305656672
# include: aggregate_11 -> feature_subset: ['aggregate_8', 'aggregate_7', 'aggregate_1', 'difference_min_max', 'aggregate_10', 'aggregate_11']. Accuracy: 68.6356916836
# include: aggregate_2 -> feature_subset: ['aggregate_8', 'aggregate_7', 'aggregate_1', 'difference_min_max', 'aggregate_10', 'aggregate_11', 'aggregate_2']. Accuracy: 68.4165203018
# 3 ['aggregate_11', 'aggregate_7', 'aggregate_1'] 71.5174330837
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 60.9467270842
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 63.0964860674
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 59.4500577832
# include: area -> feature_subset: ['area']. Accuracy: 62.1932469564
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 60.7646511189
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 59.9325203248
# include: area -> feature_subset: ['area']. Accuracy: 62.364921909
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 63.2390298545
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 63.2609929046
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 64.6649178089
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 63.5621106845
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 63.9094909521
# include: area -> feature_subset: ['area']. Accuracy: 67.9686698824
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 65.9054023698
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 62.6262134329
# include: area -> feature_subset: ['area']. Accuracy: 68.4383003155
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 66.4430807902
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 64.4532429498
# 6 ['area'] 68.4383003155
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_6 -> feature_subset: ['aggregate_6']. Accuracy: 40.5332385363
# include: aggregate_2 -> feature_subset: ['aggregate_6', 'aggregate_2']. Accuracy: 35.3809600497
# include: aggregate_1 -> feature_subset: ['aggregate_6', 'aggregate_2', 'aggregate_1']. Accuracy: 35.9329695985
# include: aggregate_3 -> feature_subset: ['aggregate_6', 'aggregate_2', 'aggregate_1', 'aggregate_3']. Accuracy: 34.3090530123
# include: aggregate_12 -> feature_subset: ['aggregate_6', 'aggregate_2', 'aggregate_1', 'aggregate_3', 'aggregate_12']. Accuracy: 37.7846835494
# include: aggregate_5 -> feature_subset: ['aggregate_6', 'aggregate_2', 'aggregate_1', 'aggregate_3', 'aggregate_12', 'aggregate_5']. Accuracy: 40.5827308341
# include: aggregate_11 -> feature_subset: ['aggregate_6', 'aggregate_2', 'aggregate_1', 'aggregate_3', 'aggregate_12', 'aggregate_5', 'aggregate_11']. Accuracy: 41.9535824606
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 39.2031083738
# include: aggregate_11 -> feature_subset: ['aggregate_12', 'aggregate_11']. Accuracy: 39.8737373568
# include: aggregate_5 -> feature_subset: ['aggregate_12', 'aggregate_11', 'aggregate_5']. Accuracy: 40.8427318424
# include: aggregate_1 -> feature_subset: ['aggregate_12', 'aggregate_11', 'aggregate_5', 'aggregate_1']. Accuracy: 40.5575353623
# include: aggregate_2 -> feature_subset: ['aggregate_12', 'aggregate_11', 'aggregate_5', 'aggregate_1', 'aggregate_2']. Accuracy: 42.1951006877
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'aggregate_11', 'aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_4']. Accuracy: 40.0918234098
# include: difference_min_max -> feature_subset: ['aggregate_12', 'aggregate_11', 'aggregate_5', 'aggregate_1', 'aggregate_2', 'aggregate_4', 'difference_min_max']. Accuracy: 39.0804947657
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 43.0950300096
# include: aggregate_6 -> feature_subset: ['aggregate_8', 'aggregate_6']. Accuracy: 43.8088961784
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_5']. Accuracy: 45.0811328271
# include: aggregate_12 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_5', 'aggregate_12']. Accuracy: 44.6015636785
# include: aggregate_11 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_5', 'aggregate_12', 'aggregate_11']. Accuracy: 44.518634463
# include: aggregate_9 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_5', 'aggregate_12', 'aggregate_11', 'aggregate_9']. Accuracy: 43.6037630245
# include: difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_5', 'aggregate_12', 'aggregate_11', 'aggregate_9', 'difference_min_max']. Accuracy: 40.7265657691
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 45.3430286833
# include: aggregate_1 -> feature_subset: ['aggregate_12', 'aggregate_1']. Accuracy: 46.2547392063
# include: aggregate_11 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_11']. Accuracy: 43.0635318873
# include: aggregate_2 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_11', 'aggregate_2']. Accuracy: 41.1928117638
# include: aggregate_5 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_11', 'aggregate_2', 'aggregate_5']. Accuracy: 41.3415814261
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_11', 'aggregate_2', 'aggregate_5', 'aggregate_4']. Accuracy: 41.6439307201
# include: aggregate_3 -> feature_subset: ['aggregate_12', 'aggregate_1', 'aggregate_11', 'aggregate_2', 'aggregate_5', 'aggregate_4', 'aggregate_3']. Accuracy: 40.9244733422
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 46.0135885135
# include: aggregate_6 -> feature_subset: ['aggregate_10', 'aggregate_6']. Accuracy: 42.9959693796
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_1']. Accuracy: 42.0253478747
# include: aggregate_8 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_1', 'aggregate_8']. Accuracy: 42.2804284198
# include: aggregate_9 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_1', 'aggregate_8', 'aggregate_9']. Accuracy: 44.3677297768
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_1', 'aggregate_8', 'aggregate_9', 'aggregate_2']. Accuracy: 44.565453459
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_6', 'aggregate_1', 'aggregate_8', 'aggregate_9', 'aggregate_2', 'aggregate_7']. Accuracy: 43.7017856718
# include: aggregate_6 -> feature_subset: ['aggregate_6']. Accuracy: 44.0185990697
# include: aggregate_12 -> feature_subset: ['aggregate_6', 'aggregate_12']. Accuracy: 41.3782749034
# include: aggregate_9 -> feature_subset: ['aggregate_6', 'aggregate_12', 'aggregate_9']. Accuracy: 41.308757038
# include: aggregate_8 -> feature_subset: ['aggregate_6', 'aggregate_12', 'aggregate_9', 'aggregate_8']. Accuracy: 40.219425528
# include: difference_min_max -> feature_subset: ['aggregate_6', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'difference_min_max']. Accuracy: 40.963871007
# include: aggregate_3 -> feature_subset: ['aggregate_6', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'difference_min_max', 'aggregate_3']. Accuracy: 41.8715020405
# include: aggregate_4 -> feature_subset: ['aggregate_6', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'difference_min_max', 'aggregate_3', 'aggregate_4']. Accuracy: 42.2505143305
# 4 ['aggregate_12', 'aggregate_1'] 46.2547392063
# --------------------------------------------------------------------------------
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 27.3643101156
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 28.2954870891
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 20.9767293756
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 34.0821612601
# include: area -> feature_subset: ['num_rooms', 'area']. Accuracy: 32.5483992291
# include: total_occupants -> feature_subset: ['num_rooms', 'area', 'total_occupants']. Accuracy: 27.105425831
# include: area -> feature_subset: ['area']. Accuracy: 33.2038747594
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 35.535542561
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 35.0360541144
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 36.2750772385
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 39.0057992028
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 32.5471361306
# include: area -> feature_subset: ['area']. Accuracy: 37.1519398509
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 40.0640742093
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 36.4188408619
# include: area -> feature_subset: ['area']. Accuracy: 36.5907802856
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 40.148081318
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 38.0565276994
# 6 ['area', 'total_occupants'] 40.148081318
# --------------------------------------------------------------------------------

# %%
import json
#json.dump(optimal_dict_median, open("optimal_dict_cv1_sensitivity.json","w"))
#json.dump(out_median, open("out_cv1_sensitivity.json","w"))

optimal_dict_median_overall = json.load(open("optimal_dict_cv1.json",'r'))
optimal_dict_median = json.load(open("optimal_dict_cv1_sensitivity.json",'r'))

# %% [markdown]
# ### Second round of cross validation- Maximising mean accuracy after removing test outlier

# %%
out_cv2 = {}
optimal_cv2 = {}
for appliance in ["fridge","hvac","dw","dr","wm","light"]:
    out_cv2[appliance] = {}
    optimal_cv2[appliance] = {}
    for feature in ["Static","Monthly"]:
        
        o, opt = find_optimal_features(df, dfc, all_homes, appliance_min, national_average, 
                                                                [appliance], 
                                       {feature:feature_map[feature]},
                                  NUM_NEIGHBOURS_MAX=7, F_length_max=7, metric="mean",
                                  train_outlier=True, test_outlier=True, outlier_features=
                                       optimal_dict_median_overall[appliance]["All"]["f"], outlier_fraction=0.1,
                             print_steps=True)
        out_cv2[appliance][feature]=o
        optimal_cv2[appliance][feature]=opt
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 68.6695087534
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 68.0135672065
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 71.5496330685
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 70.508783332
# include: area -> feature_subset: ['total_occupants', 'area']. Accuracy: 70.2950873394
# include: num_rooms -> feature_subset: ['total_occupants', 'area', 'num_rooms']. Accuracy: 70.4375293654
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 72.21187814
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 69.7242596329
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 70.3750126961
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 73.1279854876
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 71.552939564
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 68.4856977249
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 73.6863775376
# include: area -> feature_subset: ['num_rooms', 'area']. Accuracy: 71.2650201064
# include: total_occupants -> feature_subset: ['num_rooms', 'area', 'total_occupants']. Accuracy: 68.3970520814
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 73.2435654462
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 71.7899598392
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 70.1254213488
# 1 ['total_occupants', 'area', 'num_rooms'] 74.6258721051
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_9 -> feature_subset: ['aggregate_9']. Accuracy: 73.5329848207
# include: aggregate_3 -> feature_subset: ['aggregate_9', 'aggregate_3']. Accuracy: 73.5844870365
# include: aggregate_12 -> feature_subset: ['aggregate_9', 'aggregate_3', 'aggregate_12']. Accuracy: 73.9243128251
# include: aggregate_11 -> feature_subset: ['aggregate_9', 'aggregate_3', 'aggregate_12', 'aggregate_11']. Accuracy: 72.393721877
# include: difference_min_max -> feature_subset: ['aggregate_9', 'aggregate_3', 'aggregate_12', 'aggregate_11', 'difference_min_max']. Accuracy: 71.1425634459
# include: aggregate_8 -> feature_subset: ['aggregate_9', 'aggregate_3', 'aggregate_12', 'aggregate_11', 'difference_min_max', 'aggregate_8']. Accuracy: 74.5261061816
# include: aggregate_4 -> feature_subset: ['aggregate_9', 'aggregate_3', 'aggregate_12', 'aggregate_11', 'difference_min_max', 'aggregate_8', 'aggregate_4']. Accuracy: 75.2854493778
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 71.2837984065
# include: aggregate_5 -> feature_subset: ['aggregate_12', 'aggregate_5']. Accuracy: 73.2537323739
# include: ratio_min_max -> feature_subset: ['aggregate_12', 'aggregate_5', 'ratio_min_max']. Accuracy: 70.1398582326
# include: ratio_difference_min_max -> feature_subset: ['aggregate_12', 'aggregate_5', 'ratio_min_max', 'ratio_difference_min_max']. Accuracy: 76.0612953245
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'aggregate_5', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_4']. Accuracy: 75.0026026807
# include: aggregate_1 -> feature_subset: ['aggregate_12', 'aggregate_5', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1']. Accuracy: 76.62775461
# include: aggregate_2 -> feature_subset: ['aggregate_12', 'aggregate_5', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1', 'aggregate_2']. Accuracy: 76.3512013063
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 72.990028263
# include: aggregate_4 -> feature_subset: ['ratio_min_max', 'aggregate_4']. Accuracy: 74.7325529098
# include: aggregate_3 -> feature_subset: ['ratio_min_max', 'aggregate_4', 'aggregate_3']. Accuracy: 74.1782579586
# include: ratio_difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_4', 'aggregate_3', 'ratio_difference_min_max']. Accuracy: 77.0355145927
# include: aggregate_7 -> feature_subset: ['ratio_min_max', 'aggregate_4', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_7']. Accuracy: 76.9890246224
# include: aggregate_2 -> feature_subset: ['ratio_min_max', 'aggregate_4', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_7', 'aggregate_2']. Accuracy: 76.9890246224
# include: aggregate_10 -> feature_subset: ['ratio_min_max', 'aggregate_4', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_7', 'aggregate_2', 'aggregate_10']. Accuracy: 75.5810862968
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 72.9465861852
# include: aggregate_3 -> feature_subset: ['ratio_min_max', 'aggregate_3']. Accuracy: 77.2268498637
# include: ratio_difference_min_max -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max']. Accuracy: 75.5123138692
# include: aggregate_4 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4']. Accuracy: 77.1097328986
# include: aggregate_1 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1']. Accuracy: 75.9394666447
# include: aggregate_5 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1', 'aggregate_5']. Accuracy: 74.5133237097
# include: aggregate_11 -> feature_subset: ['ratio_min_max', 'aggregate_3', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1', 'aggregate_5', 'aggregate_11']. Accuracy: 75.9336307306
# include: aggregate_4 -> feature_subset: ['aggregate_4']. Accuracy: 72.7266713387
# include: ratio_min_max -> feature_subset: ['aggregate_4', 'ratio_min_max']. Accuracy: 73.1280886849
# include: aggregate_5 -> feature_subset: ['aggregate_4', 'ratio_min_max', 'aggregate_5']. Accuracy: 76.1975571207
# include: ratio_difference_min_max -> feature_subset: ['aggregate_4', 'ratio_min_max', 'aggregate_5', 'ratio_difference_min_max']. Accuracy: 73.6477690913
# include: aggregate_8 -> feature_subset: ['aggregate_4', 'ratio_min_max', 'aggregate_5', 'ratio_difference_min_max', 'aggregate_8']. Accuracy: 74.41778562
# include: aggregate_9 -> feature_subset: ['aggregate_4', 'ratio_min_max', 'aggregate_5', 'ratio_difference_min_max', 'aggregate_8', 'aggregate_9']. Accuracy: 73.8705253711
# include: aggregate_7 -> feature_subset: ['aggregate_4', 'ratio_min_max', 'aggregate_5', 'ratio_difference_min_max', 'aggregate_8', 'aggregate_9', 'aggregate_7']. Accuracy: 72.9781993573
# include: ratio_min_max -> feature_subset: ['ratio_min_max']. Accuracy: 70.9732805082
# include: aggregate_12 -> feature_subset: ['ratio_min_max', 'aggregate_12']. Accuracy: 74.2454541915
# include: aggregate_10 -> feature_subset: ['ratio_min_max', 'aggregate_12', 'aggregate_10']. Accuracy: 73.5924610206
# include: aggregate_11 -> feature_subset: ['ratio_min_max', 'aggregate_12', 'aggregate_10', 'aggregate_11']. Accuracy: 71.2767592623
# include: aggregate_7 -> feature_subset: ['ratio_min_max', 'aggregate_12', 'aggregate_10', 'aggregate_11', 'aggregate_7']. Accuracy: 72.7474666156
# include: aggregate_4 -> feature_subset: ['ratio_min_max', 'aggregate_12', 'aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_4']. Accuracy: 72.9864517907
# include: aggregate_2 -> feature_subset: ['ratio_min_max', 'aggregate_12', 'aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_4', 'aggregate_2']. Accuracy: 73.050757955
# 2 ['aggregate_12', 'aggregate_5', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_4', 'aggregate_1'] 76.3100888236
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 71.9970911374
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 70.0405623065
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 65.8284908977
# include: area -> feature_subset: ['area']. Accuracy: 76.8703025263
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 74.1824911617
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 75.5462145437
# include: area -> feature_subset: ['area']. Accuracy: 78.1017982406
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 75.8564384854
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 75.7235087188
# include: area -> feature_subset: ['area']. Accuracy: 77.6869047971
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 76.1579105776
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 75.5565731852
# include: area -> feature_subset: ['area']. Accuracy: 78.5186852336
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 76.6028607836
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 75.3353331448
# include: area -> feature_subset: ['area']. Accuracy: 78.4001728343
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 76.6460479047
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 75.5837447941
# 5 ['area'] 78.5186852336
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_5 -> feature_subset: ['aggregate_5']. Accuracy: 79.01287546
# include: aggregate_3 -> feature_subset: ['aggregate_5', 'aggregate_3']. Accuracy: 79.6951945173
# include: aggregate_7 -> feature_subset: ['aggregate_5', 'aggregate_3', 'aggregate_7']. Accuracy: 79.3304499232
# include: aggregate_10 -> feature_subset: ['aggregate_5', 'aggregate_3', 'aggregate_7', 'aggregate_10']. Accuracy: 78.7755917651
# include: aggregate_12 -> feature_subset: ['aggregate_5', 'aggregate_3', 'aggregate_7', 'aggregate_10', 'aggregate_12']. Accuracy: 79.1468637602
# include: difference_min_max -> feature_subset: ['aggregate_5', 'aggregate_3', 'aggregate_7', 'aggregate_10', 'aggregate_12', 'difference_min_max']. Accuracy: 81.0415148042
# include: aggregate_9 -> feature_subset: ['aggregate_5', 'aggregate_3', 'aggregate_7', 'aggregate_10', 'aggregate_12', 'difference_min_max', 'aggregate_9']. Accuracy: 81.0766316422
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 80.0558058421
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_2']. Accuracy: 81.0905085546
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_10']. Accuracy: 81.1578652143
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_10', 'aggregate_5']. Accuracy: 81.7390187221
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_10', 'aggregate_5', 'aggregate_9']. Accuracy: 81.6700738628
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_10', 'aggregate_5', 'aggregate_9', 'aggregate_12']. Accuracy: 82.0667496903
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_10', 'aggregate_5', 'aggregate_9', 'aggregate_12', 'aggregate_6']. Accuracy: 83.0381111049
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 81.9172423895
# include: aggregate_4 -> feature_subset: ['aggregate_7', 'aggregate_4']. Accuracy: 82.0600507445
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_11']. Accuracy: 81.7812355541
# include: aggregate_8 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_11', 'aggregate_8']. Accuracy: 81.6358897618
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_11', 'aggregate_8', 'aggregate_9']. Accuracy: 81.8347870187
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_11', 'aggregate_8', 'aggregate_9', 'aggregate_12']. Accuracy: 81.8674066712
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_4', 'aggregate_11', 'aggregate_8', 'aggregate_9', 'aggregate_12', 'aggregate_5']. Accuracy: 82.1693251234
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 81.7360102273
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_2']. Accuracy: 82.6981844601
# include: aggregate_3 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3']. Accuracy: 82.9748998146
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_10']. Accuracy: 82.4817192929
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_10', 'aggregate_5']. Accuracy: 82.7890548154
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_10', 'aggregate_5', 'aggregate_6']. Accuracy: 82.8995643816
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_2', 'aggregate_3', 'aggregate_10', 'aggregate_5', 'aggregate_6', 'aggregate_11']. Accuracy: 82.9506933108
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 81.9553896494
# include: aggregate_12 -> feature_subset: ['aggregate_8', 'aggregate_12']. Accuracy: 82.0685836292
# include: aggregate_7 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_7']. Accuracy: 82.673741574
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_7', 'aggregate_5']. Accuracy: 82.5872618227
# include: aggregate_3 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_7', 'aggregate_5', 'aggregate_3']. Accuracy: 82.5920535238
# include: aggregate_4 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_7', 'aggregate_5', 'aggregate_3', 'aggregate_4']. Accuracy: 82.1864953582
# include: difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_7', 'aggregate_5', 'aggregate_3', 'aggregate_4', 'difference_min_max']. Accuracy: 82.3777824458
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 81.3284574684
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_5']. Accuracy: 81.7405326556
# include: aggregate_7 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_7']. Accuracy: 82.2366346803
# include: aggregate_10 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_7', 'aggregate_10']. Accuracy: 82.6834415691
# include: aggregate_4 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_7', 'aggregate_10', 'aggregate_4']. Accuracy: 82.5112204381
# include: aggregate_3 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_7', 'aggregate_10', 'aggregate_4', 'aggregate_3']. Accuracy: 82.7015535547
# include: aggregate_2 -> feature_subset: ['aggregate_8', 'aggregate_5', 'aggregate_7', 'aggregate_10', 'aggregate_4', 'aggregate_3', 'aggregate_2']. Accuracy: 82.7405374967
# 2 ['aggregate_7', 'aggregate_2', 'aggregate_10', 'aggregate_5', 'aggregate_9', 'aggregate_12', 'aggregate_6'] 83.0381111049
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 32.9178643906
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 27.6904879137
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 27.1155976923
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 34.9482674565
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 35.4615637709
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 32.3756810911
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 35.2157834
# include: area -> feature_subset: ['num_rooms', 'area']. Accuracy: 35.5786300141
# include: total_occupants -> feature_subset: ['num_rooms', 'area', 'total_occupants']. Accuracy: 35.9149908176
# include: area -> feature_subset: ['area']. Accuracy: 38.4728761845
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 37.3646063341
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 34.5063165889
# include: area -> feature_subset: ['area']. Accuracy: 38.2001437853
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 37.3515514059
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 35.5225040498
# include: area -> feature_subset: ['area']. Accuracy: 37.5833699274
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 38.6348435662
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 36.9149221248
# 6 ['area', 'total_occupants'] 38.6348435662
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_6 -> feature_subset: ['aggregate_6']. Accuracy: 38.2099453953
# include: aggregate_9 -> feature_subset: ['aggregate_6', 'aggregate_9']. Accuracy: 37.1356974507
# include: aggregate_8 -> feature_subset: ['aggregate_6', 'aggregate_9', 'aggregate_8']. Accuracy: 39.6865529342
# include: difference_min_max -> feature_subset: ['aggregate_6', 'aggregate_9', 'aggregate_8', 'difference_min_max']. Accuracy: 39.5155058853
# include: aggregate_4 -> feature_subset: ['aggregate_6', 'aggregate_9', 'aggregate_8', 'difference_min_max', 'aggregate_4']. Accuracy: 38.7340646566
# include: aggregate_5 -> feature_subset: ['aggregate_6', 'aggregate_9', 'aggregate_8', 'difference_min_max', 'aggregate_4', 'aggregate_5']. Accuracy: 38.2891624544
# include: aggregate_11 -> feature_subset: ['aggregate_6', 'aggregate_9', 'aggregate_8', 'difference_min_max', 'aggregate_4', 'aggregate_5', 'aggregate_11']. Accuracy: 37.5733970552
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 39.87749362
# include: aggregate_12 -> feature_subset: ['aggregate_8', 'aggregate_12']. Accuracy: 38.7099618278
# include: aggregate_6 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_6']. Accuracy: 39.1908338839
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_6', 'aggregate_5']. Accuracy: 40.1855342771
# include: aggregate_4 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_6', 'aggregate_5', 'aggregate_4']. Accuracy: 40.2969953595
# include: aggregate_1 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_6', 'aggregate_5', 'aggregate_4', 'aggregate_1']. Accuracy: 40.7657700112
# include: aggregate_2 -> feature_subset: ['aggregate_8', 'aggregate_12', 'aggregate_6', 'aggregate_5', 'aggregate_4', 'aggregate_1', 'aggregate_2']. Accuracy: 40.776021858
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 41.3514264582
# include: aggregate_6 -> feature_subset: ['aggregate_8', 'aggregate_6']. Accuracy: 41.2477342564
# include: aggregate_12 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_12']. Accuracy: 42.0363167653
# include: aggregate_2 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_12', 'aggregate_2']. Accuracy: 41.6074679357
# include: aggregate_11 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_12', 'aggregate_2', 'aggregate_11']. Accuracy: 41.2343705474
# include: aggregate_9 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_12', 'aggregate_2', 'aggregate_11', 'aggregate_9']. Accuracy: 40.9950755926
# include: difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_12', 'aggregate_2', 'aggregate_11', 'aggregate_9', 'difference_min_max']. Accuracy: 41.7041777644
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 43.5872704188
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_7']. Accuracy: 40.081743361
# include: aggregate_9 -> feature_subset: ['aggregate_10', 'aggregate_7', 'aggregate_9']. Accuracy: 41.4687676526
# include: aggregate_5 -> feature_subset: ['aggregate_10', 'aggregate_7', 'aggregate_9', 'aggregate_5']. Accuracy: 41.9886708773
# include: aggregate_8 -> feature_subset: ['aggregate_10', 'aggregate_7', 'aggregate_9', 'aggregate_5', 'aggregate_8']. Accuracy: 41.3036137678
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_7', 'aggregate_9', 'aggregate_5', 'aggregate_8', 'aggregate_2']. Accuracy: 41.0152627323
# include: aggregate_6 -> feature_subset: ['aggregate_10', 'aggregate_7', 'aggregate_9', 'aggregate_5', 'aggregate_8', 'aggregate_2', 'aggregate_6']. Accuracy: 40.9914183934
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 41.5684082943
# include: aggregate_8 -> feature_subset: ['aggregate_10', 'aggregate_8']. Accuracy: 41.4207095649
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_8', 'aggregate_2']. Accuracy: 41.2617380287
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_8', 'aggregate_2', 'aggregate_11']. Accuracy: 41.5200815041
# include: aggregate_9 -> feature_subset: ['aggregate_10', 'aggregate_8', 'aggregate_2', 'aggregate_11', 'aggregate_9']. Accuracy: 41.3734458003
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_8', 'aggregate_2', 'aggregate_11', 'aggregate_9', 'aggregate_7']. Accuracy: 41.7761559942
# include: aggregate_6 -> feature_subset: ['aggregate_10', 'aggregate_8', 'aggregate_2', 'aggregate_11', 'aggregate_9', 'aggregate_7', 'aggregate_6']. Accuracy: 41.8643266955
# include: aggregate_8 -> feature_subset: ['aggregate_8']. Accuracy: 41.8614206152
# include: aggregate_6 -> feature_subset: ['aggregate_8', 'aggregate_6']. Accuracy: 42.0392577659
# include: aggregate_9 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_9']. Accuracy: 41.9281077841
# include: difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_9', 'difference_min_max']. Accuracy: 41.9410838223
# include: ratio_difference_min_max -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_9', 'difference_min_max', 'ratio_difference_min_max']. Accuracy: 41.8113779501
# include: aggregate_5 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_9', 'difference_min_max', 'ratio_difference_min_max', 'aggregate_5']. Accuracy: 41.6318530719
# include: aggregate_12 -> feature_subset: ['aggregate_8', 'aggregate_6', 'aggregate_9', 'difference_min_max', 'ratio_difference_min_max', 'aggregate_5', 'aggregate_12']. Accuracy: 41.6621047729
# 5 ['aggregate_10'] 43.7823977725
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 31.5053154135
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 36.2001516655
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 33.5903942341
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 41.0989504203
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 41.6799062175
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 35.1779245563
# include: total_occupants -> feature_subset: ['total_occupants']. Accuracy: 42.622226841
# include: num_rooms -> feature_subset: ['total_occupants', 'num_rooms']. Accuracy: 40.75348458
# include: area -> feature_subset: ['total_occupants', 'num_rooms', 'area']. Accuracy: 41.0618049412
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 42.0299471115
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 41.9638975998
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 42.086691098
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 41.3357279517
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 42.615754765
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 42.5646006854
# include: num_rooms -> feature_subset: ['num_rooms']. Accuracy: 41.7790385559
# include: total_occupants -> feature_subset: ['num_rooms', 'total_occupants']. Accuracy: 42.2992892729
# include: area -> feature_subset: ['num_rooms', 'total_occupants', 'area']. Accuracy: 42.4939323975
# 5 ['num_rooms', 'total_occupants', 'area'] 42.8462021546
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 39.0010275805
# include: aggregate_12 -> feature_subset: ['aggregate_1', 'aggregate_12']. Accuracy: 38.6150570418
# include: aggregate_10 -> feature_subset: ['aggregate_1', 'aggregate_12', 'aggregate_10']. Accuracy: 38.1597520013
# include: ratio_min_max -> feature_subset: ['aggregate_1', 'aggregate_12', 'aggregate_10', 'ratio_min_max']. Accuracy: 38.1789972846
# include: aggregate_8 -> feature_subset: ['aggregate_1', 'aggregate_12', 'aggregate_10', 'ratio_min_max', 'aggregate_8']. Accuracy: 39.5060245546
# include: aggregate_5 -> feature_subset: ['aggregate_1', 'aggregate_12', 'aggregate_10', 'ratio_min_max', 'aggregate_8', 'aggregate_5']. Accuracy: 41.3959113916
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_12', 'aggregate_10', 'ratio_min_max', 'aggregate_8', 'aggregate_5', 'aggregate_4']. Accuracy: 41.1530817182
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 42.202812915
# include: ratio_min_max -> feature_subset: ['aggregate_12', 'ratio_min_max']. Accuracy: 43.8342910694
# include: ratio_difference_min_max -> feature_subset: ['aggregate_12', 'ratio_min_max', 'ratio_difference_min_max']. Accuracy: 42.0226893798
# include: aggregate_2 -> feature_subset: ['aggregate_12', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_2']. Accuracy: 41.0104329681
# include: aggregate_3 -> feature_subset: ['aggregate_12', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_2', 'aggregate_3']. Accuracy: 41.0724237312
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_2', 'aggregate_3', 'aggregate_4']. Accuracy: 40.3327643717
# include: aggregate_11 -> feature_subset: ['aggregate_12', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_2', 'aggregate_3', 'aggregate_4', 'aggregate_11']. Accuracy: 40.1816588628
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 41.2461927204
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_1']. Accuracy: 42.6677269311
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_1', 'aggregate_12']. Accuracy: 41.89836385
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_1', 'aggregate_12', 'aggregate_7']. Accuracy: 41.8262692349
# include: aggregate_5 -> feature_subset: ['aggregate_10', 'aggregate_1', 'aggregate_12', 'aggregate_7', 'aggregate_5']. Accuracy: 42.0274098116
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_1', 'aggregate_12', 'aggregate_7', 'aggregate_5', 'aggregate_4']. Accuracy: 41.8524004538
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_1', 'aggregate_12', 'aggregate_7', 'aggregate_5', 'aggregate_4', 'aggregate_11']. Accuracy: 41.9629231991
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 42.8853684203
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_12']. Accuracy: 42.157825086
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7']. Accuracy: 42.5651177891
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11']. Accuracy: 42.7471991125
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4']. Accuracy: 42.9866058644
# include: aggregate_5 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_5']. Accuracy: 41.8644011562
# include: difference_min_max -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_7', 'aggregate_11', 'aggregate_4', 'aggregate_5', 'difference_min_max']. Accuracy: 41.8064620321
# include: aggregate_12 -> feature_subset: ['aggregate_12']. Accuracy: 42.8158269462
# include: aggregate_10 -> feature_subset: ['aggregate_12', 'aggregate_10']. Accuracy: 43.7848500155
# include: aggregate_2 -> feature_subset: ['aggregate_12', 'aggregate_10', 'aggregate_2']. Accuracy: 43.7220705173
# include: aggregate_11 -> feature_subset: ['aggregate_12', 'aggregate_10', 'aggregate_2', 'aggregate_11']. Accuracy: 42.9790833517
# include: aggregate_3 -> feature_subset: ['aggregate_12', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_3']. Accuracy: 43.1742976067
# include: aggregate_1 -> feature_subset: ['aggregate_12', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_3', 'aggregate_1']. Accuracy: 42.3948649676
# include: aggregate_4 -> feature_subset: ['aggregate_12', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_3', 'aggregate_1', 'aggregate_4']. Accuracy: 42.4968102743
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 43.6753693626
# include: aggregate_12 -> feature_subset: ['aggregate_10', 'aggregate_12']. Accuracy: 43.9388196379
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_11']. Accuracy: 43.8530354628
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_11', 'aggregate_1']. Accuracy: 43.4887316548
# include: aggregate_3 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_11', 'aggregate_1', 'aggregate_3']. Accuracy: 43.5850740423
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_11', 'aggregate_1', 'aggregate_3', 'aggregate_4']. Accuracy: 43.3311173953
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_12', 'aggregate_11', 'aggregate_1', 'aggregate_3', 'aggregate_4', 'aggregate_2']. Accuracy: 43.1105249893
# 5 ['aggregate_12', 'aggregate_10'] 44.07933462
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 54.8909336516
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 55.244636935
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 49.9203050388
# include: area -> feature_subset: ['area']. Accuracy: 57.499113037
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 54.8943009883
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 51.5145072787
# include: area -> feature_subset: ['area']. Accuracy: 55.8994811997
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 54.4210431623
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 53.657614426
# include: area -> feature_subset: ['area']. Accuracy: 56.9854745015
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 55.8504020743
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 54.4709236257
# include: area -> feature_subset: ['area']. Accuracy: 58.252067376
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 56.6969678535
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 54.8131794265
# include: area -> feature_subset: ['area']. Accuracy: 58.8316622519
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 57.4102852026
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 55.1579301508
# 6 ['area'] 58.8316622519
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 62.243938091
# include: aggregate_10 -> feature_subset: ['aggregate_11', 'aggregate_10']. Accuracy: 63.2406997486
# include: aggregate_2 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2']. Accuracy: 63.8675085828
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1']. Accuracy: 63.5709843968
# include: difference_min_max -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max']. Accuracy: 62.7772501318
# include: aggregate_4 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max', 'aggregate_4']. Accuracy: 59.9009950001
# include: aggregate_6 -> feature_subset: ['aggregate_11', 'aggregate_10', 'aggregate_2', 'aggregate_1', 'difference_min_max', 'aggregate_4', 'aggregate_6']. Accuracy: 59.1018828298
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 62.0431597971
# include: aggregate_4 -> feature_subset: ['aggregate_11', 'aggregate_4']. Accuracy: 62.3179347553
# include: aggregate_10 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_10']. Accuracy: 61.3702101932
# include: aggregate_5 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_5']. Accuracy: 62.5754750161
# include: aggregate_2 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_5', 'aggregate_2']. Accuracy: 61.5215507817
# include: aggregate_7 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_5', 'aggregate_2', 'aggregate_7']. Accuracy: 59.9593678009
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_5', 'aggregate_2', 'aggregate_7', 'aggregate_1']. Accuracy: 61.1818171636
# include: aggregate_10 -> feature_subset: ['aggregate_10']. Accuracy: 58.1716120167
# include: aggregate_11 -> feature_subset: ['aggregate_10', 'aggregate_11']. Accuracy: 57.9089591781
# include: aggregate_7 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_7']. Accuracy: 59.6921023698
# include: aggregate_1 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_1']. Accuracy: 60.2066838661
# include: aggregate_4 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_4']. Accuracy: 60.0340558318
# include: aggregate_3 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_4', 'aggregate_3']. Accuracy: 60.1111908145
# include: aggregate_2 -> feature_subset: ['aggregate_10', 'aggregate_11', 'aggregate_7', 'aggregate_1', 'aggregate_4', 'aggregate_3', 'aggregate_2']. Accuracy: 60.1521817094
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 58.785764668
# include: aggregate_1 -> feature_subset: ['aggregate_7', 'aggregate_1']. Accuracy: 58.7727685269
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_1', 'aggregate_10']. Accuracy: 58.6586542456
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_2']. Accuracy: 58.4664618183
# include: aggregate_11 -> feature_subset: ['aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11']. Accuracy: 58.1725175452
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'difference_min_max']. Accuracy: 58.4913258373
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'difference_min_max', 'aggregate_6']. Accuracy: 58.8472695625
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 57.8543242183
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_12']. Accuracy: 58.4955382944
# include: aggregate_9 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_9']. Accuracy: 58.0814854961
# include: aggregate_8 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_9', 'aggregate_8']. Accuracy: 58.16689187
# include: aggregate_10 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'aggregate_10']. Accuracy: 57.8889946953
# include: aggregate_6 -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'aggregate_10', 'aggregate_6']. Accuracy: 58.2084113028
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_12', 'aggregate_9', 'aggregate_8', 'aggregate_10', 'aggregate_6', 'difference_min_max']. Accuracy: 58.1995155156
# include: aggregate_7 -> feature_subset: ['aggregate_7']. Accuracy: 57.6102338358
# include: aggregate_8 -> feature_subset: ['aggregate_7', 'aggregate_8']. Accuracy: 58.436768229
# include: aggregate_2 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_2']. Accuracy: 58.27273638
# include: aggregate_5 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_2', 'aggregate_5']. Accuracy: 57.9130103207
# include: difference_min_max -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_2', 'aggregate_5', 'difference_min_max']. Accuracy: 57.9683216603
# include: aggregate_12 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_2', 'aggregate_5', 'difference_min_max', 'aggregate_12']. Accuracy: 57.9690209228
# include: aggregate_4 -> feature_subset: ['aggregate_7', 'aggregate_8', 'aggregate_2', 'aggregate_5', 'difference_min_max', 'aggregate_12', 'aggregate_4']. Accuracy: 57.9575322999
# 1 ['aggregate_11', 'aggregate_10', 'aggregate_2'] 63.8675085828
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Static
# ********************
# include: area -> feature_subset: ['area']. Accuracy: 36.529827275
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 36.927630288
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 34.900526127
# include: area -> feature_subset: ['area']. Accuracy: 45.321900524
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 39.0877058392
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 32.2764346416
# include: area -> feature_subset: ['area']. Accuracy: 44.242528659
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 43.454811204
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 36.75738974
# include: area -> feature_subset: ['area']. Accuracy: 44.0369197293
# include: total_occupants -> feature_subset: ['area', 'total_occupants']. Accuracy: 40.9113646106
# include: num_rooms -> feature_subset: ['area', 'total_occupants', 'num_rooms']. Accuracy: 37.9733255309
# include: area -> feature_subset: ['area']. Accuracy: 45.7274267871
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 40.4279234608
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 35.6090805762
# include: area -> feature_subset: ['area']. Accuracy: 45.9350532185
# include: num_rooms -> feature_subset: ['area', 'num_rooms']. Accuracy: 42.1984025094
# include: total_occupants -> feature_subset: ['area', 'num_rooms', 'total_occupants']. Accuracy: 35.7883154522
# 6 ['area'] 45.9350532185
# --------------------------------------------------------------------------------
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# Monthly
# ********************
# include: aggregate_9 -> feature_subset: ['aggregate_9']. Accuracy: 36.1344936407
# include: difference_min_max -> feature_subset: ['aggregate_9', 'difference_min_max']. Accuracy: 37.1380643254
# include: aggregate_10 -> feature_subset: ['aggregate_9', 'difference_min_max', 'aggregate_10']. Accuracy: 35.9709511711
# include: aggregate_7 -> feature_subset: ['aggregate_9', 'difference_min_max', 'aggregate_10', 'aggregate_7']. Accuracy: 35.0844075856
# include: ratio_min_max -> feature_subset: ['aggregate_9', 'difference_min_max', 'aggregate_10', 'aggregate_7', 'ratio_min_max']. Accuracy: 32.5922893589
# include: aggregate_6 -> feature_subset: ['aggregate_9', 'difference_min_max', 'aggregate_10', 'aggregate_7', 'ratio_min_max', 'aggregate_6']. Accuracy: 32.7041468014
# include: aggregate_11 -> feature_subset: ['aggregate_9', 'difference_min_max', 'aggregate_10', 'aggregate_7', 'ratio_min_max', 'aggregate_6', 'aggregate_11']. Accuracy: 33.0870520576
# include: difference_min_max -> feature_subset: ['difference_min_max']. Accuracy: 42.2623928719
# include: aggregate_9 -> feature_subset: ['difference_min_max', 'aggregate_9']. Accuracy: 44.4926269966
# include: ratio_min_max -> feature_subset: ['difference_min_max', 'aggregate_9', 'ratio_min_max']. Accuracy: 46.2716603941
# include: aggregate_8 -> feature_subset: ['difference_min_max', 'aggregate_9', 'ratio_min_max', 'aggregate_8']. Accuracy: 45.8785361542
# include: aggregate_10 -> feature_subset: ['difference_min_max', 'aggregate_9', 'ratio_min_max', 'aggregate_8', 'aggregate_10']. Accuracy: 46.5360973928
# include: aggregate_2 -> feature_subset: ['difference_min_max', 'aggregate_9', 'ratio_min_max', 'aggregate_8', 'aggregate_10', 'aggregate_2']. Accuracy: 46.5360973928
# include: aggregate_7 -> feature_subset: ['difference_min_max', 'aggregate_9', 'ratio_min_max', 'aggregate_8', 'aggregate_10', 'aggregate_2', 'aggregate_7']. Accuracy: 45.6855021891
# include: difference_min_max -> feature_subset: ['difference_min_max']. Accuracy: 43.250544945
# include: aggregate_12 -> feature_subset: ['difference_min_max', 'aggregate_12']. Accuracy: 42.69631962
# include: aggregate_5 -> feature_subset: ['difference_min_max', 'aggregate_12', 'aggregate_5']. Accuracy: 43.2376317594
# include: aggregate_4 -> feature_subset: ['difference_min_max', 'aggregate_12', 'aggregate_5', 'aggregate_4']. Accuracy: 43.2376317594
# include: aggregate_2 -> feature_subset: ['difference_min_max', 'aggregate_12', 'aggregate_5', 'aggregate_4', 'aggregate_2']. Accuracy: 42.8700217616
# include: aggregate_10 -> feature_subset: ['difference_min_max', 'aggregate_12', 'aggregate_5', 'aggregate_4', 'aggregate_2', 'aggregate_10']. Accuracy: 42.9347764053
# include: aggregate_3 -> feature_subset: ['difference_min_max', 'aggregate_12', 'aggregate_5', 'aggregate_4', 'aggregate_2', 'aggregate_10', 'aggregate_3']. Accuracy: 42.9347764053
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 43.734800829
# include: aggregate_10 -> feature_subset: ['aggregate_1', 'aggregate_10']. Accuracy: 44.3839354402
# include: aggregate_2 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2']. Accuracy: 42.5766248245
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11']. Accuracy: 42.2420992415
# include: aggregate_12 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_12']. Accuracy: 41.8275122036
# include: aggregate_8 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_12', 'aggregate_8']. Accuracy: 41.1601086967
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'aggregate_10', 'aggregate_2', 'aggregate_11', 'aggregate_12', 'aggregate_8', 'aggregate_3']. Accuracy: 40.0068564996
# include: aggregate_11 -> feature_subset: ['aggregate_11']. Accuracy: 42.6359145183
# include: aggregate_12 -> feature_subset: ['aggregate_11', 'aggregate_12']. Accuracy: 42.9338614188
# include: aggregate_10 -> feature_subset: ['aggregate_11', 'aggregate_12', 'aggregate_10']. Accuracy: 43.0854167692
# include: aggregate_1 -> feature_subset: ['aggregate_11', 'aggregate_12', 'aggregate_10', 'aggregate_1']. Accuracy: 42.4344753071
# include: aggregate_3 -> feature_subset: ['aggregate_11', 'aggregate_12', 'aggregate_10', 'aggregate_1', 'aggregate_3']. Accuracy: 42.4054229066
# include: aggregate_2 -> feature_subset: ['aggregate_11', 'aggregate_12', 'aggregate_10', 'aggregate_1', 'aggregate_3', 'aggregate_2']. Accuracy: 41.9310737724
# include: aggregate_4 -> feature_subset: ['aggregate_11', 'aggregate_12', 'aggregate_10', 'aggregate_1', 'aggregate_3', 'aggregate_2', 'aggregate_4']. Accuracy: 41.9310737724
# include: aggregate_1 -> feature_subset: ['aggregate_1']. Accuracy: 42.7241802087
# include: aggregate_2 -> feature_subset: ['aggregate_1', 'aggregate_2']. Accuracy: 41.9622507807
# include: aggregate_11 -> feature_subset: ['aggregate_1', 'aggregate_2', 'aggregate_11']. Accuracy: 42.2509422184
# include: aggregate_4 -> feature_subset: ['aggregate_1', 'aggregate_2', 'aggregate_11', 'aggregate_4']. Accuracy: 42.1688195366
# include: aggregate_10 -> feature_subset: ['aggregate_1', 'aggregate_2', 'aggregate_11', 'aggregate_4', 'aggregate_10']. Accuracy: 42.1688195366
# include: aggregate_3 -> feature_subset: ['aggregate_1', 'aggregate_2', 'aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_3']. Accuracy: 42.1636218764
# include: aggregate_12 -> feature_subset: ['aggregate_1', 'aggregate_2', 'aggregate_11', 'aggregate_4', 'aggregate_10', 'aggregate_3', 'aggregate_12']. Accuracy: 41.3314910344
# 2 ['difference_min_max', 'aggregate_9', 'ratio_min_max', 'aggregate_8', 'aggregate_10'] 46.5360973928
# --------------------------------------------------------------------------------

# %%
json.dump(optimal_cv2, open("optimal_cv2_sensitivity.json",'w'))
json.dump(out_cv2, open("out_cv2_sensitivity.json",'w'))

# %%
out_cv2 = json.load(open("out_cv2_sensitivity.json",'r'))

# %%
out_cv2['light']['Monthly']['light']['Monthly']
# Out:
# {u'1': {u'accuracy': 37.13806432541721,
#   u'f': [u'aggregate_9', u'difference_min_max']},
#  u'2': {u'accuracy': 46.53609739279665,
#   u'f': [u'difference_min_max',
#    u'aggregate_9',
#    u'ratio_min_max',
#    u'aggregate_8',
#    u'aggregate_10']},
#  u'3': {u'accuracy': 43.250544944968965, u'f': [u'difference_min_max']},
#  u'4': {u'accuracy': 44.38393544023571,
#   u'f': [u'aggregate_1', u'aggregate_10']},
#  u'5': {u'accuracy': 43.08541676916261,
#   u'f': [u'aggregate_11', u'aggregate_12', u'aggregate_10']},
#  u'6': {u'accuracy': 42.724180208651696, u'f': [u'aggregate_1']}}

# %%
top_f = {
    'dr':{
        'Monthly':{
        'f':[u'aggregate_12', u'aggregate_10'],
        'k':5
        },
        'Static':{
            'f':[u'num_rooms', u'total_occupants', u'area'],
            'k':5
            
        }
        },
    'dw':
    {
        'Static':
        {
            'k':6,
            'f':[u'area', u'total_occupants']
        },
        'Monthly':
        {
            'k':5,
            'f':[u'aggregate_10']
            
        }
    },
    'fridge':
    {
        'Monthly':
        {
            'k':2,
            'f':[u'aggregate_12',
               u'aggregate_5',
               u'ratio_min_max',
               u'ratio_difference_min_max',
               u'aggregate_4',
               u'aggregate_1']
        },
        'Static':
        {
            'k':1,
            'f':[u'total_occupants', u'area', u'num_rooms']
            
        }
    },
    
    'hvac':
    {
        'Static':
        {
            'k':6,
            'f':[u'area']
        },
        'Monthly':
        {
            'k':2,
            'f':[u'aggregate_7',
               u'aggregate_2',
               u'aggregate_10',
               u'aggregate_5',
               u'aggregate_9',
               u'aggregate_12',
               u'aggregate_6']
        }
        
    },
    'wm':
       { 
        'Monthly':
        {
            'k':1,
            'f':[u'aggregate_11', u'aggregate_10', u'aggregate_2']
        },
        'Static':
        {
            'k':6,
            'f':[u'area']
        }
    },
    'light':
    {
        'Static':
        {
            'k':6,
            'f':[u'area']
        },
        'Monthly':
        {
            'k':2,
            'f':[u'difference_min_max',
               u'aggregate_9',
               u'ratio_min_max',
               u'aggregate_8',
               u'aggregate_10']
        }
    }
    
    
    
}

# %%
optimal_all_median = json.load(open("optimal_dict_cv1.json",'r'))
optimal_median_sensitivity = json.load(open("optimal_dict_cv1_sensitivity.json",'r'))
optimal_mean_sensitivity = top_f
optimal_all_mean = json.load(open("optimal_cv2.json",'r'))

# %%
s = {}
for appliance in ['fridge','dw','dr','hvac','light','wm']:
    print appliance
    s[appliance] = {}
    for feature in ["All",'Monthly','Static']:
        s[appliance][feature] = {}
        if feature=="All":
            k=optimal_all_mean[appliance]['All'][appliance]['All']['k']
            f=optimal_all_mean[appliance]['All'][appliance]['All']['f']
            train_outlier_f = optimal_all_median[appliance]['All']['f']
        else:
            k=top_f[appliance][feature]['k']
            f=top_f[appliance][feature]['f']
            train_outlier_f = optimal_median_sensitivity[appliance][feature]['f']
            
        temp = create_predictions(df, dfc, all_homes, appliance_min,
                                          national_average, appliance=appliance, 
                                          feature=f,
                                          NUM_NEIGHBOURS=k, train_outlier=True, test_outlier=True,
                                          outlier_features=train_outlier_f, outlier_fraction=0.1)


        errors = {}
        if appliance =="hvac":
            start_month, end_month = 5, 11
        else:
            start_month, end_month = 1, 13
        for i in range(start_month, end_month):
            errors[i] = percentage_error(temp[i]["gt"], temp[i]["pred"])
        error_df = pd.DataFrame(errors)
        accur_df = 100-error_df
        accur_df[accur_df<0]=0
        tdf = accur_df
        if appliance =="hvac":
            for home in [624, 1953, 6636, 6836, 7769, 9922]:
                tdf.loc[home, 5]=np.NaN
                tdf.loc[home, 10]=np.NaN

        s[appliance][feature] = tdf.dropna().mean().mean()
# Out:
# fridge
# dw
# dr
# hvac
# light
# wm
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/sklearn/covariance/robust_covariance.py:161: RuntimeWarning: Warning! det > previous_det (-53.251586074133130 > -inf)
#   % (det, previous_det), RuntimeWarning)

# %%
appliance_name_mapping = {"dr": "Dryer", "wm": "Washing\nmachine",
                          "fridge":"Fridge","light":"Lights",
                          "hvac":"HVAC","dw":"Dish\nwasher"}

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sen = pd.DataFrame(s)

# %%
sen
# Out:
#                 dr         dw     fridge       hvac      light         wm
# All      46.676615  45.756176  79.253608  83.218137  49.357385  66.443781
# Monthly  44.762341  40.427641  76.617781  83.195882  46.536097  62.767684
# Static   44.470307  37.390754  71.570956  79.983186  52.871403  58.156344

# %%
sen = sen.rename(columns=appliance_name_mapping).T

# %%
from common_functions import latexify, format_axes
latexify()

tableau20blind =  [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
  
# Rescale to values between 0 and 1
for i in range(len(tableau20blind)):  
    r, g, b = tableau20blind[i]  
    tableau20blind[i] = (r / 255., g / 255., b / 255.)

# %%
sen[['Static','Monthly','All']].ix[['HVAC','Fridge','Washing\nmachine',
                                    'Lights','Dryer','Dish\nwasher']].plot(kind="bar",rot=0, colors=tableau20blind)
plt.ylim((0, 100));
plt.ylabel("Energy accuracy(\%)\n(Higher is better)");
plt.tight_layout()
format_axes(plt.gca())
plt.savefig("/Users/nipunbatra/git/monthly-disaggregation/results/features_sensitivity.pdf",bbox_inches="tight")
plt.savefig("/Users/nipunbatra/git/monthly-disaggregation/results/features_sensitivity.png",bbox_inches="tight")
