# %% [markdown]
# ### Load data set with features

# %%
from create_df import read_df
df, dfc, all_homes, appliance_min, national_average = read_df()

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
run all_functions.py

# %%
run features.py

# %%
import json

# %%
from sklearn.cross_validation import KFold

# %%
num_homes=10
total_homes = len(df.ix[all_homes['hvac']])
folds = np.ceil(total_homes*1./num_homes)
                  
kf = KFold(len(df.ix[all_homes['hvac']]), n_folds=folds, shuffle=True, random_state=2)
for train, test in kf:
    print sum(train), sum(test)
# Out:
# 375 153
# 414 114
# 412 116
# 383 145

# %%
import sys

from sklearn.neighbors import KNeighborsRegressor
from sklearn.cross_validation import KFold
from sklearn.cross_validation import ShuffleSplit

o = {}
for appliance in ["hvac"]:
    o[appliance] = {}
    appliance_df = df.ix[all_homes[appliance]]
    if appliance=="hvac":
        start, stop=5, 11
    else:
        start, stop=1, 13
    for num_homes in [7]:
        print "NUM HOME", num_homes
        o[appliance][num_homes] = {}
        
        total_homes = len(appliance_df)
        
        
       
        
        for random_seed in range(50):
            o[appliance][num_homes][random_seed] = {}
            rs = ShuffleSplit(len(appliance_df), n_iter=1, train_size=num_homes, random_state=random_seed)

            for train, test in rs:
                train_homes = appliance_df.index.values[train]
                test_homes = appliance_df.index.values[test]
                all_home_appliance = deepcopy(all_homes)
                all_home_appliance[appliance] = train_homes
                _, optimal_dict = find_optimal_features(df.ix[train_homes], dfc.ix[train_homes],
                                                            all_home_appliance, appliance_min, 
                                                            national_average, [appliance], 
                                                             {"All":feature_map["Monthly"]},
                                                              NUM_NEIGHBOURS_MAX=6, F_length_max=6, metric="mean",
                                                              train_outlier=True, test_outlier=False, outlier_features=None, outlier_fraction=0.1,
                                                              print_steps=False)
                f = optimal_dict[appliance]['All']['f']
                k = optimal_dict[appliance]['All']['k']
                for month in range(start, stop):   

                    sys.stdout.flush()

                    clf = KNeighborsRegressor(n_neighbors=k)
                    clf.fit(df.ix[train_homes][f], df.ix[train_homes]['%s_%d' %(appliance, month)])
                    pred = pd.Series(clf.predict(df.ix[test_homes][f]), index=test_homes)
                    gt = df.ix[test_homes]['%s_%d' %(appliance, month)]
                    accur = 100-(pred-gt).abs().div(gt).mul(100)
                    accur[accur<0]=0
                    o[appliance][num_homes][random_seed][month]=accur.mean().mean()
            print random_seed, pd.Series(o[appliance][num_homes][random_seed]).mean()
        print "NUM HOME:",num_homes, pd.DataFrame(o[appliance][num_homes]).mean().mean()
                #o[appliance][num_homes] = pd.Series(o[appliance][num_homes][month]).mean()
# Out:
# NUM HOME 7
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['difference_min_max', 'aggregate_12', 'aggregate_6'] 79.4727818244
# --------------------------------------------------------------------------------
# 0 68.9502588199
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['difference_min_max', 'aggregate_6'] 72.3038895721
# --------------------------------------------------------------------------------
# 1 61.6155189164
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_9', 'aggregate_5'] 88.3940537662
# --------------------------------------------------------------------------------
# 2 73.5329499205
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_4'] 75.836383297
# --------------------------------------------------------------------------------
# 3 61.5282383139
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_6'] 72.5559686084
# --------------------------------------------------------------------------------
# 4 81.176752809
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_8'] 81.1768244868
# --------------------------------------------------------------------------------
# 5 63.8425846881
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['difference_min_max', 'aggregate_7'] 79.6414474645
# --------------------------------------------------------------------------------
# 6 59.9973566148
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6', 'aggregate_9'] 77.8809905446
# --------------------------------------------------------------------------------
# 7 81.9258117791
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_11'] 73.2965293789
# --------------------------------------------------------------------------------
# 8 61.6043462754
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_2', 'aggregate_3', 'aggregate_1', 'aggregate_8', 'aggregate_6', 'aggregate_5'] 81.0709330886
# --------------------------------------------------------------------------------
# 9 56.9580760757
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_6'] 73.8734602314
# --------------------------------------------------------------------------------
# 10 68.7728219943
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6', 'aggregate_12', 'aggregate_5', 'aggregate_9', 'aggregate_11'] 75.5593030942
# --------------------------------------------------------------------------------
# 11 73.1173491022
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['difference_min_max', 'aggregate_7', 'aggregate_10'] 77.4726913254
# --------------------------------------------------------------------------------
# 12 62.3691267139
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_9', 'aggregate_4'] 71.7904395453
# --------------------------------------------------------------------------------
# 13 53.5001198997
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['difference_min_max'] 69.0395272946
# --------------------------------------------------------------------------------
# 14 73.9750929597
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_5', 'aggregate_12'] 71.8687281572
# --------------------------------------------------------------------------------
# 15 74.3933839521
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_2', 'aggregate_5', 'aggregate_11', 'aggregate_6', 'ratio_min_max'] 81.8062301108
# --------------------------------------------------------------------------------
# 16 61.9066694874
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_7', 'difference_min_max'] 79.4314901573
# --------------------------------------------------------------------------------
# 17 69.1368087231
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_12', 'aggregate_1', 'aggregate_7'] 75.9688972337
# --------------------------------------------------------------------------------
# 18 70.3631532479
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_9', 'difference_min_max', 'aggregate_1'] 69.9345660766
# --------------------------------------------------------------------------------
# 19 76.8706288708
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6'] 81.0212442627
# --------------------------------------------------------------------------------
# 20 77.3104883294
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['difference_min_max'] 74.2356987782
# --------------------------------------------------------------------------------
# 21 79.1117174267
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5', 'aggregate_12'] 73.6614050325
# --------------------------------------------------------------------------------
# 22 54.2842901837
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5'] 75.7003940193
# --------------------------------------------------------------------------------
# 23 59.4936793477
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_10'] 71.7585472447
# --------------------------------------------------------------------------------
# 24 61.6789497518
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6'] 71.6724238426
# --------------------------------------------------------------------------------
# 25 70.0214096482
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_10'] 68.763932733
# --------------------------------------------------------------------------------
# 26 76.3807002462
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_11', 'aggregate_10'] 65.5810997774
# --------------------------------------------------------------------------------
# 27 77.8382655866
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_9', 'aggregate_10', 'aggregate_7'] 76.2851296047
# --------------------------------------------------------------------------------
# 28 60.9968817521
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_8', 'aggregate_6', 'aggregate_10'] 64.8345944454
# --------------------------------------------------------------------------------
# 29 84.4975616712
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_3', 'aggregate_5'] 66.7225547545
# --------------------------------------------------------------------------------
# 30 68.4601105481
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6', 'aggregate_2', 'aggregate_7'] 79.3394877009
# --------------------------------------------------------------------------------
# 31 58.3758777945
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-289-4558a4246281> in <module>()
#      37                                                               NUM_NEIGHBOURS_MAX=6, F_length_max=6, metric="mean",
#      38                                                               train_outlier=True, test_outlier=False, outlier_features=None, outlier_fraction=0.1,
# ---> 39                                                               print_steps=False)
#      40                 f = optimal_dict[appliance]['All']['f']
#      41                 k = optimal_dict[appliance]['All']['k']
#
# /Users/nipunbatra/git/monthly-disaggregation/code/all_functions.py in find_optimal_features(df, dfc, all_homes, appliance_min, national_average, appliance_list, feature_map, NUM_NEIGHBOURS_MAX, F_length_max, metric, train_outlier, test_outlier, outlier_features, outlier_fraction, print_steps)
#     463                     train_outlier, test_outlier, outlier_features, outlier_fraction,
#     464                     metric,
# --> 465                     F_length_max, criterion_function, print_steps)
#     466
#     467                 best_accur = 0.0
#
# /Users/nipunbatra/git/monthly-disaggregation/code/all_functions.py in seq_forw_select(df, dfc, all_homes, appliance_min, national_average, appliance, features, NUM_NEIGHBOURS, train_outlier, test_outlier, outlier_features, outlier_fraction, metric, max_k, criterion_func, print_steps)
#     367                                             appliance, feat_sub + [x], NUM_NEIGHBOURS,
#     368                                             train_outlier, test_outlier, outlier_features, outlier_fraction,
# --> 369                                             metric)
#     370             if crit_func_eval > crit_func_max:
#     371                 crit_func_max = crit_func_eval
#
# /Users/nipunbatra/git/monthly-disaggregation/code/all_functions.py in criterion_function(df, dfc, all_homes, appliance_min, national_average, appliance, feature, NUM_NEIGHBOURS, train_outlier, test_outlier, outlier_features, outlier_fraction, metric)
#     245     temp = create_predictions(df, dfc, all_homes, appliance_min, national_average,
#     246                               appliance, feature, NUM_NEIGHBOURS, train_outlier, test_outlier, outlier_features,
# --> 247                               outlier_fraction)
#     248     errors = {}
#     249     if appliance =="hvac":
#
# /Users/nipunbatra/git/monthly-disaggregation/code/all_functions.py in create_predictions(df, dfc, all_homes, appliance_min, national_average, appliance, feature, NUM_NEIGHBOURS, train_outlier, test_outlier, outlier_features, outlier_fraction)
#     171             #clf.fit(preprocessing.normalize(df3[feature_columns[feature]].values[train]), y3.values[train])
#     172
# --> 173             clf.fit(df3[feature].ix[inlier_homes.index], inlier_homes.values)
#     174             #out_pred.append(clf.predict(preprocessing.normalize(df3[feature_columns[feature]].values[test])))
#     175             out_pred.append(clf.predict(df3[feature].values[test]))
#
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in __getitem__(self, key)
#    1789         if isinstance(key, (Series, np.ndarray, Index, list)):
#    1790             # either boolean or fancy integer index
# -> 1791             return self._getitem_array(key)
#    1792         elif isinstance(key, DataFrame):
#    1793             return self._getitem_frame(key)
#
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/pandas/core/frame.pyc in _getitem_array(self, key)
#    1833             return self.take(indexer, axis=0, convert=False)
#    1834         else:
# -> 1835             indexer = self.ix._convert_to_indexer(key, axis=1)
#    1836             return self.take(indexer, axis=1, convert=True)
#    1837
#
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/pandas/core/indexing.pyc in _convert_to_indexer(self, obj, axis, is_setter)
#    1076                     objarr = obj.values
#    1077                 else:
# -> 1078                     objarr = _asarray_tuplesafe(obj)
#    1079
#    1080                 # The index may want to handle a list indexer differently
#
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/pandas/core/common.pyc in _asarray_tuplesafe(values, dtype)
#    2357         return lib.list_to_object_array(values)
#    2358
# -> 2359     result = np.asarray(values, dtype=dtype)
#    2360
#    2361     if issubclass(result.dtype.type, compat.string_types):
#
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/numpy/core/numeric.pyc in asarray(a, dtype, order)
#     472
#     473     """
# --> 474     return array(a, dtype, copy=False, order=order)
#     475
#     476 def asanyarray(a, dtype=None, order=None):
#
# KeyboardInterrupt:

# %%
import seaborn as sns

# %%
pd.DataFrame({k:pd.DataFrame(o['hvac'][k]).mean() for k in [7, 12, 17, 22, 27]}).to_csv("/Users/nipunbatra/git/monthly-disaggregation/hvac_num_homes_static.csv")

# %%
sns.tsplot(pd.DataFrame({k:pd.DataFrame(o['hvac'][k]).mean() for k in [7, 12, 17, 22, 27]}).values, 
           ci=95, time=[7, 12, 17, 22, 27], marker='o', err_style='ci_bars')
#plt.ylim((0, 100))
plt.xlim((5, 30))
plt.xlabel("Num homes used for training")
plt.ylabel("Accuracy")
#plt.savefig("/Users/nipunbatra/Desktop/hvac_static.pdf")
#plt.savefig("/Users/nipunbatra/Desktop/hvac_static.png")
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-291-8c2fb3271a89> in <module>()
# ----> 1 sns.tsplot(pd.DataFrame({k:pd.DataFrame(o['hvac'][k]).mean() for k in [7, 12, 17, 22, 27]}).values,
#       2            ci=95, time=[7, 12, 17, 22, 27], marker='o', err_style='ci_bars')
#       3 #plt.ylim((0, 100))
#       4 plt.xlim((5, 30))
#       5 plt.xlabel("Num homes used for training")
#
# <ipython-input-291-8c2fb3271a89> in <dictcomp>((k,))
# ----> 1 sns.tsplot(pd.DataFrame({k:pd.DataFrame(o['hvac'][k]).mean() for k in [7, 12, 17, 22, 27]}).values,
#       2            ci=95, time=[7, 12, 17, 22, 27], marker='o', err_style='ci_bars')
#       3 #plt.ylim((0, 100))
#       4 plt.xlim((5, 30))
#       5 plt.xlabel("Num homes used for training")
#
# KeyError: 12

# %%
appliance="hvac"
feature=["aggregate_10"]
temp = create_predictions(df, dfc, all_homes, appliance_min, national_average,
                              appliance, feature, NUM_NEIGHBOURS=2, train_outlier=True, test_outlier=False, outlier_features=None,
                              outlier_fraction=0.1)
errors = {}
errors_new = {}
if appliance =="hvac":
    start_month, end_month = 5, 11
else:
    start_month, end_month = 1, 13
for i in range(start_month, end_month):
    errors[i] = percentage_error(temp[i]["gt"], temp[i]["pred"])
    gt = temp[i]["gt"]
    pred = temp[i]["pred"]
    
    errors_new[i] = (gt-pred).abs().div(gt).mul(100)

error_df = pd.DataFrame(errors)
accur_df = 100-error_df
accur_df[accur_df<0]=0

error_new_df = pd.DataFrame(errors_new)
accur_new_df = 100-error_new_df
accur_new_df[accur_new_df<0]=0

# %%
accur_df.mean()
# Out:
# 5     64.748961
# 6     64.419043
# 7     68.682391
# 8     73.694641
# 9     76.917797
# 10    67.894369
# dtype: float64

# %%
accur_new_df.mean()
# Out:
# 5     64.748961
# 6     64.419043
# 7     68.682391
# 8     73.694641
# 9     76.917797
# 10    67.894369
# dtype: float64

# %%
import sys

from sklearn.neighbors import KNeighborsRegressor
o = {}
for appliance in ["hvac","fridge","light","dw","dr","wm"]:
    o[appliance] = {}
    if appliance=="hvac":
        start, stop=5, 11
    else:
        start, stop=1, 13
    for num_homes in [10]:
        o[appliance][num_homes] = {}
        for random_seed in range(10):
            o[appliance][num_homes][random_seed] = {}
            a,optimal_dict,train_homes = find_optimal_features_subset(df, dfc, all_homes, appliance_min, 
                                                                          national_average, [appliance], 
                                 {"All":feature_map["Monthly"]},
                              NUM_NEIGHBOURS_MAX=7, F_length_max=6, metric="mean",
                              train_outlier=True, test_outlier=False, outlier_features=None, outlier_fraction=0.1,
                              print_steps=False,random_seed=random_seed, num_homes=num_homes)
            f = optimal_dict[appliance]['All']['f']
            k = optimal_dict[appliance]['All']['k']
            for month in range(start, stop):   
                
                print appliance, num_homes, random_seed, month
                sys.stdout.flush()
                
                clf = KNeighborsRegressor(n_neighbors=k)
                clf.fit(df.ix[train_homes][f], df.ix[train_homes]['%s_%d' %(appliance, month)])
                test_homes = np.setdiff1d(all_homes[appliance], train_homes)
                pred = pd.Series(clf.predict(df.ix[test_homes][f]), index=test_homes)
                gt = df.ix[test_homes]['%s_%d' %(appliance, month)]
                accur = 100-(pred-gt).abs().div(gt).mul(100)
                accur[accur<0]=0
                o[appliance][num_homes][random_seed][month]=accur.mean().mean()
            o[appliance][num_homes][random_seed] = pd.Series(o[appliance][num_homes][random_seed][month]).mean()
        o[appliance][num_homes] = o[appliance][num_homes].values()
# Out:
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_8', 'aggregate_5', 'aggregate_11'] 80.0891783422
# --------------------------------------------------------------------------------
# hvac 10 0 5
# hvac 10 0 6
# hvac 10 0 7
# hvac 10 0 8
# hvac 10 0 9
# hvac 10 0 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_6', 'aggregate_4'] 82.4589373494
# --------------------------------------------------------------------------------
# hvac 10 1 5
# hvac 10 1 6
# hvac 10 1 7
# hvac 10 1 8
# hvac 10 1 9
# hvac 10 1 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_7', 'aggregate_12', 'aggregate_3'] 85.7272998467
# --------------------------------------------------------------------------------
# hvac 10 2 5
# hvac 10 2 6
# hvac 10 2 7
# hvac 10 2 8
# hvac 10 2 9
# hvac 10 2 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_2', 'aggregate_6', 'difference_min_max'] 72.308146264
# --------------------------------------------------------------------------------
# hvac 10 3 5
# hvac 10 3 6
# hvac 10 3 7
# hvac 10 3 8
# hvac 10 3 9
# hvac 10 3 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_9', 'difference_min_max', 'aggregate_8', 'aggregate_10', 'aggregate_5'] 80.0551843096
# --------------------------------------------------------------------------------
# hvac 10 4 5
# hvac 10 4 6
# hvac 10 4 7
# hvac 10 4 8
# hvac 10 4 9
# hvac 10 4 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['difference_min_max', 'aggregate_5', 'aggregate_10', 'ratio_min_max'] 84.7956236118
# --------------------------------------------------------------------------------
# hvac 10 5 5
# hvac 10 5 6
# hvac 10 5 7
# hvac 10 5 8
# hvac 10 5 9
# hvac 10 5 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_10', 'aggregate_8', 'aggregate_5', 'aggregate_11'] 75.9613352493
# --------------------------------------------------------------------------------
# hvac 10 6 5
# hvac 10 6 6
# hvac 10 6 7
# hvac 10 6 8
# hvac 10 6 9
# hvac 10 6 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_8', 'aggregate_1', 'aggregate_12'] 81.5551594873
# --------------------------------------------------------------------------------
# hvac 10 7 5
# hvac 10 7 6
# hvac 10 7 7
# hvac 10 7 8
# hvac 10 7 9
# hvac 10 7 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_8', 'aggregate_5', 'aggregate_1'] 76.2163953253
# --------------------------------------------------------------------------------
# hvac 10 8 5
# hvac 10 8 6
# hvac 10 8 7
# hvac 10 8 8
# hvac 10 8 9
# hvac 10 8 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# hvac
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_8', 'aggregate_4', 'aggregate_1', 'aggregate_2', 'aggregate_5'] 80.4641595667
# --------------------------------------------------------------------------------
# hvac 10 9 5
# hvac 10 9 6
# hvac 10 9 7
# hvac 10 9 8
# hvac 10 9 9
# hvac 10 9 10
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_12', 'aggregate_1', 'ratio_min_max'] 83.6085226665
# --------------------------------------------------------------------------------
# fridge 10 0 1
# fridge 10 0 2
# fridge 10 0 3
# fridge 10 0 4
# fridge 10 0 5
# fridge 10 0 6
# fridge 10 0 7
# fridge 10 0 8
# fridge 10 0 9
# fridge 10 0 10
# fridge 10 0 11
# fridge 10 0 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5', 'aggregate_3', 'aggregate_2'] 73.0728300881
# --------------------------------------------------------------------------------
# fridge 10 1 1
# fridge 10 1 2
# fridge 10 1 3
# fridge 10 1 4
# fridge 10 1 5
# fridge 10 1 6
# fridge 10 1 7
# fridge 10 1 8
# fridge 10 1 9
# fridge 10 1 10
# fridge 10 1 11
# fridge 10 1 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['ratio_min_max'] 85.2667792484
# --------------------------------------------------------------------------------
# fridge 10 2 1
# fridge 10 2 2
# fridge 10 2 3
# fridge 10 2 4
# fridge 10 2 5
# fridge 10 2 6
# fridge 10 2 7
# fridge 10 2 8
# fridge 10 2 9
# fridge 10 2 10
# fridge 10 2 11
# fridge 10 2 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5', 'aggregate_6'] 76.2848046787
# --------------------------------------------------------------------------------
# fridge 10 3 1
# fridge 10 3 2
# fridge 10 3 3
# fridge 10 3 4
# fridge 10 3 5
# fridge 10 3 6
# fridge 10 3 7
# fridge 10 3 8
# fridge 10 3 9
# fridge 10 3 10
# fridge 10 3 11
# fridge 10 3 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_9', 'ratio_min_max', 'aggregate_3', 'aggregate_4', 'aggregate_8'] 72.89146905
# --------------------------------------------------------------------------------
# fridge 10 4 1
# fridge 10 4 2
# fridge 10 4 3
# fridge 10 4 4
# fridge 10 4 5
# fridge 10 4 6
# fridge 10 4 7
# fridge 10 4 8
# fridge 10 4 9
# fridge 10 4 10
# fridge 10 4 11
# fridge 10 4 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_12', 'aggregate_1'] 81.6846566184
# --------------------------------------------------------------------------------
# fridge 10 5 1
# fridge 10 5 2
# fridge 10 5 3
# fridge 10 5 4
# fridge 10 5 5
# fridge 10 5 6
# fridge 10 5 7
# fridge 10 5 8
# fridge 10 5 9
# fridge 10 5 10
# fridge 10 5 11
# fridge 10 5 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_3'] 82.383902114
# --------------------------------------------------------------------------------
# fridge 10 6 1
# fridge 10 6 2
# fridge 10 6 3
# fridge 10 6 4
# fridge 10 6 5
# fridge 10 6 6
# fridge 10 6 7
# fridge 10 6 8
# fridge 10 6 9
# fridge 10 6 10
# fridge 10 6 11
# fridge 10 6 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_3'] 84.8348488444
# --------------------------------------------------------------------------------
# fridge 10 7 1
# fridge 10 7 2
# fridge 10 7 3
# fridge 10 7 4
# fridge 10 7 5
# fridge 10 7 6
# fridge 10 7 7
# fridge 10 7 8
# fridge 10 7 9
# fridge 10 7 10
# fridge 10 7 11
# fridge 10 7 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_3', 'aggregate_4'] 81.5050509333
# --------------------------------------------------------------------------------
# fridge 10 8 1
# fridge 10 8 2
# fridge 10 8 3
# fridge 10 8 4
# fridge 10 8 5
# fridge 10 8 6
# fridge 10 8 7
# fridge 10 8 8
# fridge 10 8 9
# fridge 10 8 10
# fridge 10 8 11
# fridge 10 8 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# fridge
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_5'] 79.7009219527
# --------------------------------------------------------------------------------
# fridge 10 9 1
# fridge 10 9 2
# fridge 10 9 3
# fridge 10 9 4
# fridge 10 9 5
# fridge 10 9 6
# fridge 10 9 7
# fridge 10 9 8
# fridge 10 9 9
# fridge 10 9 10
# fridge 10 9 11
# fridge 10 9 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_9', 'aggregate_5', 'difference_min_max'] 44.5319946832
# --------------------------------------------------------------------------------
# light 10 0 1
# light 10 0 2
# light 10 0 3
# light 10 0 4
# light 10 0 5
# light 10 0 6
# light 10 0 7
# light 10 0 8
# light 10 0 9
# light 10 0 10
# light 10 0 11
# light 10 0 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_2', 'aggregate_4'] 53.8605619657
# --------------------------------------------------------------------------------
# light 10 1 1
# light 10 1 2
# light 10 1 3
# light 10 1 4
# light 10 1 5
# light 10 1 6
# light 10 1 7
# light 10 1 8
# light 10 1 9
# light 10 1 10
# light 10 1 11
# light 10 1 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_5'] 48.8700280016
# --------------------------------------------------------------------------------
# light 10 2 1
# light 10 2 2
# light 10 2 3
# light 10 2 4
# light 10 2 5
# light 10 2 6
# light 10 2 7
# light 10 2 8
# light 10 2 9
# light 10 2 10
# light 10 2 11
# light 10 2 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_8', 'difference_min_max'] 59.73044942
# --------------------------------------------------------------------------------
# light 10 3 1
# light 10 3 2
# light 10 3 3
# light 10 3 4
# light 10 3 5
# light 10 3 6
# light 10 3 7
# light 10 3 8
# light 10 3 9
# light 10 3 10
# light 10 3 11
# light 10 3 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['difference_min_max', 'aggregate_8', 'aggregate_3'] 62.5122044629
# --------------------------------------------------------------------------------
# light 10 4 1
# light 10 4 2
# light 10 4 3
# light 10 4 4
# light 10 4 5
# light 10 4 6
# light 10 4 7
# light 10 4 8
# light 10 4 9
# light 10 4 10
# light 10 4 11
# light 10 4 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_8', 'aggregate_10'] 48.4915378044
# --------------------------------------------------------------------------------
# light 10 5 1
# light 10 5 2
# light 10 5 3
# light 10 5 4
# light 10 5 5
# light 10 5 6
# light 10 5 7
# light 10 5 8
# light 10 5 9
# light 10 5 10
# light 10 5 11
# light 10 5 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_8', 'difference_min_max', 'aggregate_2', 'ratio_min_max', 'ratio_difference_min_max'] 54.1832518203
# --------------------------------------------------------------------------------
# light 10 6 1
# light 10 6 2
# light 10 6 3
# light 10 6 4
# light 10 6 5
# light 10 6 6
# light 10 6 7
# light 10 6 8
# light 10 6 9
# light 10 6 10
# light 10 6 11
# light 10 6 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_5', 'aggregate_8', 'aggregate_1'] 44.7764344523
# --------------------------------------------------------------------------------
# light 10 7 1
# light 10 7 2
# light 10 7 3
# light 10 7 4
# light 10 7 5
# light 10 7 6
# light 10 7 7
# light 10 7 8
# light 10 7 9
# light 10 7 10
# light 10 7 11
# light 10 7 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_5', 'aggregate_9', 'aggregate_2'] 52.3720637973
# --------------------------------------------------------------------------------
# light 10 8 1
# light 10 8 2
# light 10 8 3
# light 10 8 4
# light 10 8 5
# light 10 8 6
# light 10 8 7
# light 10 8 8
# light 10 8 9
# light 10 8 10
# light 10 8 11
# light 10 8 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# light
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_8'] 55.2326637499
# --------------------------------------------------------------------------------
# light 10 9 1
# light 10 9 2
# light 10 9 3
# light 10 9 4
# light 10 9 5
# light 10 9 6
# light 10 9 7
# light 10 9 8
# light 10 9 9
# light 10 9 10
# light 10 9 11
# light 10 9 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 6 ['aggregate_2', 'aggregate_10', 'aggregate_12', 'aggregate_3'] 45.2043807413
# --------------------------------------------------------------------------------
# dw 10 0 1
# dw 10 0 2
# dw 10 0 3
# dw 10 0 4
# dw 10 0 5
# dw 10 0 6
# dw 10 0 7
# dw 10 0 8
# dw 10 0 9
# dw 10 0 10
# dw 10 0 11
# dw 10 0 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_10', 'aggregate_8', 'aggregate_5', 'aggregate_9'] 44.860481748
# --------------------------------------------------------------------------------
# dw 10 1 1
# dw 10 1 2
# dw 10 1 3
# dw 10 1 4
# dw 10 1 5
# dw 10 1 6
# dw 10 1 7
# dw 10 1 8
# dw 10 1 9
# dw 10 1 10
# dw 10 1 11
# dw 10 1 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_12', 'ratio_min_max', 'aggregate_11'] 37.7038054973
# --------------------------------------------------------------------------------
# dw 10 2 1
# dw 10 2 2
# dw 10 2 3
# dw 10 2 4
# dw 10 2 5
# dw 10 2 6
# dw 10 2 7
# dw 10 2 8
# dw 10 2 9
# dw 10 2 10
# dw 10 2 11
# dw 10 2 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_5', 'aggregate_2'] 50.5631850241
# --------------------------------------------------------------------------------
# dw 10 3 1
# dw 10 3 2
# dw 10 3 3
# dw 10 3 4
# dw 10 3 5
# dw 10 3 6
# dw 10 3 7
# dw 10 3 8
# dw 10 3 9
# dw 10 3 10
# dw 10 3 11
# dw 10 3 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_1', 'ratio_min_max', 'ratio_difference_min_max'] 43.502824841
# --------------------------------------------------------------------------------
# dw 10 4 1
# dw 10 4 2
# dw 10 4 3
# dw 10 4 4
# dw 10 4 5
# dw 10 4 6
# dw 10 4 7
# dw 10 4 8
# dw 10 4 9
# dw 10 4 10
# dw 10 4 11
# dw 10 4 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5'] 46.3733351808
# --------------------------------------------------------------------------------
# dw 10 5 1
# dw 10 5 2
# dw 10 5 3
# dw 10 5 4
# dw 10 5 5
# dw 10 5 6
# dw 10 5 7
# dw 10 5 8
# dw 10 5 9
# dw 10 5 10
# dw 10 5 11
# dw 10 5 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_8', 'aggregate_9', 'aggregate_5'] 46.0889388742
# --------------------------------------------------------------------------------
# dw 10 6 1
# dw 10 6 2
# dw 10 6 3
# dw 10 6 4
# dw 10 6 5
# dw 10 6 6
# dw 10 6 7
# dw 10 6 8
# dw 10 6 9
# dw 10 6 10
# dw 10 6 11
# dw 10 6 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_3', 'aggregate_5', 'aggregate_9', 'aggregate_2', 'ratio_min_max', 'aggregate_1'] 44.4441576676
# --------------------------------------------------------------------------------
# dw 10 7 1
# dw 10 7 2
# dw 10 7 3
# dw 10 7 4
# dw 10 7 5
# dw 10 7 6
# dw 10 7 7
# dw 10 7 8
# dw 10 7 9
# dw 10 7 10
# dw 10 7 11
# dw 10 7 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_5', 'aggregate_2', 'aggregate_11', 'ratio_min_max', 'aggregate_10', 'aggregate_12'] 52.1694077939
# --------------------------------------------------------------------------------
# dw 10 8 1
# dw 10 8 2
# dw 10 8 3
# dw 10 8 4
# dw 10 8 5
# dw 10 8 6
# dw 10 8 7
# dw 10 8 8
# dw 10 8 9
# dw 10 8 10
# dw 10 8 11
# dw 10 8 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dw
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 5 ['aggregate_10', 'ratio_min_max'] 45.9552791378
# --------------------------------------------------------------------------------
# dw 10 9 1
# dw 10 9 2
# dw 10 9 3
# dw 10 9 4
# dw 10 9 5
# dw 10 9 6
# dw 10 9 7
# dw 10 9 8
# dw 10 9 9
# dw 10 9 10
# dw 10 9 11
# dw 10 9 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_6', 'aggregate_1', 'aggregate_11'] 46.991537247
# --------------------------------------------------------------------------------
# dr 10 0 1
# dr 10 0 2
# dr 10 0 3
# dr 10 0 4
# dr 10 0 5
# dr 10 0 6
# dr 10 0 7
# dr 10 0 8
# dr 10 0 9
# dr 10 0 10
# dr 10 0 11
# dr 10 0 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 6 ['aggregate_10', 'aggregate_5', 'aggregate_6', 'ratio_min_max', 'aggregate_12', 'ratio_difference_min_max'] 46.348908818
# --------------------------------------------------------------------------------
# dr 10 1 1
# dr 10 1 2
# dr 10 1 3
# dr 10 1 4
# dr 10 1 5
# dr 10 1 6
# dr 10 1 7
# dr 10 1 8
# dr 10 1 9
# dr 10 1 10
# dr 10 1 11
# dr 10 1 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_9', 'aggregate_1', 'aggregate_7', 'aggregate_2', 'aggregate_6'] 40.8427176389
# --------------------------------------------------------------------------------
# dr 10 2 1
# dr 10 2 2
# dr 10 2 3
# dr 10 2 4
# dr 10 2 5
# dr 10 2 6
# dr 10 2 7
# dr 10 2 8
# dr 10 2 9
# dr 10 2 10
# dr 10 2 11
# dr 10 2 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_12', 'ratio_min_max'] 52.9112147105
# --------------------------------------------------------------------------------
# dr 10 3 1
# dr 10 3 2
# dr 10 3 3
# dr 10 3 4
# dr 10 3 5
# dr 10 3 6
# dr 10 3 7
# dr 10 3 8
# dr 10 3 9
# dr 10 3 10
# dr 10 3 11
# dr 10 3 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_9', 'aggregate_7', 'difference_min_max'] 37.6824953984
# --------------------------------------------------------------------------------
# dr 10 4 1
# dr 10 4 2
# dr 10 4 3
# dr 10 4 4
# dr 10 4 5
# dr 10 4 6
# dr 10 4 7
# dr 10 4 8
# dr 10 4 9
# dr 10 4 10
# dr 10 4 11
# dr 10 4 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_7', 'difference_min_max', 'aggregate_1'] 52.9446609658
# --------------------------------------------------------------------------------
# dr 10 5 1
# dr 10 5 2
# dr 10 5 3
# dr 10 5 4
# dr 10 5 5
# dr 10 5 6
# dr 10 5 7
# dr 10 5 8
# dr 10 5 9
# dr 10 5 10
# dr 10 5 11
# dr 10 5 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 6 ['aggregate_11', 'aggregate_12'] 54.2676844106
# --------------------------------------------------------------------------------
# dr 10 6 1
# dr 10 6 2
# dr 10 6 3
# dr 10 6 4
# dr 10 6 5
# dr 10 6 6
# dr 10 6 7
# dr 10 6 8
# dr 10 6 9
# dr 10 6 10
# dr 10 6 11
# dr 10 6 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_1', 'aggregate_2', 'ratio_min_max', 'ratio_difference_min_max', 'aggregate_11'] 42.8489680558
# --------------------------------------------------------------------------------
# dr 10 7 1
# dr 10 7 2
# dr 10 7 3
# dr 10 7 4
# dr 10 7 5
# dr 10 7 6
# dr 10 7 7
# dr 10 7 8
# dr 10 7 9
# dr 10 7 10
# dr 10 7 11
# dr 10 7 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_4', 'aggregate_5', 'aggregate_2', 'aggregate_1', 'aggregate_3'] 41.1609524348
# --------------------------------------------------------------------------------
# dr 10 8 1
# dr 10 8 2
# dr 10 8 3
# dr 10 8 4
# dr 10 8 5
# dr 10 8 6
# dr 10 8 7
# dr 10 8 8
# dr 10 8 9
# dr 10 8 10
# dr 10 8 11
# dr 10 8 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# dr
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_3', 'aggregate_4'] 40.1656024064
# --------------------------------------------------------------------------------
# dr 10 9 1
# dr 10 9 2
# dr 10 9 3
# dr 10 9 4
# dr 10 9 5
# dr 10 9 6
# dr 10 9 7
# dr 10 9 8
# dr 10 9 9
# dr 10 9 10
# dr 10 9 11
# dr 10 9 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 1 ['aggregate_5', 'aggregate_11', 'aggregate_6', 'aggregate_4'] 58.6856600839
# --------------------------------------------------------------------------------
# wm 10 0 1
# wm 10 0 2
# wm 10 0 3
# wm 10 0 4
# wm 10 0 5
# wm 10 0 6
# wm 10 0 7
# wm 10 0 8
# wm 10 0 9
# wm 10 0 10
# wm 10 0 11
# wm 10 0 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_11', 'aggregate_2'] 60.4465606299
# --------------------------------------------------------------------------------
# wm 10 1 1
# wm 10 1 2
# wm 10 1 3
# wm 10 1 4
# wm 10 1 5
# wm 10 1 6
# wm 10 1 7
# wm 10 1 8
# wm 10 1 9
# wm 10 1 10
# wm 10 1 11
# wm 10 1 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_11', 'aggregate_2', 'aggregate_10', 'aggregate_5'] 66.8698606709
# --------------------------------------------------------------------------------
# wm 10 2 1
# wm 10 2 2
# wm 10 2 3
# wm 10 2 4
# wm 10 2 5
# wm 10 2 6
# wm 10 2 7
# wm 10 2 8
# wm 10 2 9
# wm 10 2 10
# wm 10 2 11
# wm 10 2 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 5 ['ratio_min_max'] 65.5042538722
# --------------------------------------------------------------------------------
# wm 10 3 1
# wm 10 3 2
# wm 10 3 3
# wm 10 3 4
# wm 10 3 5
# wm 10 3 6
# wm 10 3 7
# wm 10 3 8
# wm 10 3 9
# wm 10 3 10
# wm 10 3 11
# wm 10 3 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 3 ['aggregate_7', 'aggregate_1', 'aggregate_10', 'aggregate_2'] 59.5740909737
# --------------------------------------------------------------------------------
# wm 10 4 1
# wm 10 4 2
# wm 10 4 3
# wm 10 4 4
# wm 10 4 5
# wm 10 4 6
# wm 10 4 7
# wm 10 4 8
# wm 10 4 9
# wm 10 4 10
# wm 10 4 11
# wm 10 4 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 4 ['aggregate_11'] 71.0106851593
# --------------------------------------------------------------------------------
# wm 10 5 1
# wm 10 5 2
# wm 10 5 3
# wm 10 5 4
# wm 10 5 5
# wm 10 5 6
# wm 10 5 7
# wm 10 5 8
# wm 10 5 9
# wm 10 5 10
# wm 10 5 11
# wm 10 5 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 5 ['ratio_min_max'] 65.8280078321
# --------------------------------------------------------------------------------
# wm 10 6 1
# wm 10 6 2
# wm 10 6 3
# wm 10 6 4
# wm 10 6 5
# wm 10 6 6
# wm 10 6 7
# wm 10 6 8
# wm 10 6 9
# wm 10 6 10
# wm 10 6 11
# wm 10 6 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 6 ['aggregate_5', 'ratio_min_max', 'aggregate_10', 'ratio_difference_min_max'] 67.3163384134
# --------------------------------------------------------------------------------
# wm 10 7 1
# wm 10 7 2
# wm 10 7 3
# wm 10 7 4
# wm 10 7 5
# wm 10 7 6
# wm 10 7 7
# wm 10 7 8
# wm 10 7 9
# wm 10 7 10
# wm 10 7 11
# wm 10 7 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 5 ['aggregate_4', 'ratio_min_max', 'aggregate_11'] 61.1758830417
# --------------------------------------------------------------------------------
# wm 10 8 1
# wm 10 8 2
# wm 10 8 3
# wm 10 8 4
# wm 10 8 5
# wm 10 8 6
# wm 10 8 7
# wm 10 8 8
# wm 10 8 9
# wm 10 8 10
# wm 10 8 11
# wm 10 8 12
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# wm
# %%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%%
# ********************
# All
# ********************
# 2 ['aggregate_11', 'aggregate_10', 'aggregate_5'] 62.9005610701
# --------------------------------------------------------------------------------
# wm 10 9 1
# wm 10 9 2
# wm 10 9 3
# wm 10 9 4
# wm 10 9 5
# wm 10 9 6
# wm 10 9 7
# wm 10 9 8
# wm 10 9 9
# wm 10 9 10
# wm 10 9 11
# wm 10 9 12

# %%
appliance="fridge"
pd.Series(o[appliance][10]).plot(kind="box",label=appliance)

# %%
o[appliance]
# Out:
# {10: {0: 64.048430850862133},
#  15: {0: 59.832796095091076},
#  20: {0: 64.752953520276307}}

# %%
o[appliance]
# Out:
# {10: {0: 64.650257340519772},
#  15: {0: 59.832796095091076},
#  20: {0: 70.596354522818601}}

# %%
o[appliance]
# Out:
# {10: {0: 56.181039909549369},
#  11: {0: 53.839262737242692},
#  15: {0: 57.109780976630304},
#  20: {0: 51.969433707156547}}

# %%
len(feature_map["Monthly"])
# Out:
# 15

# %%
output = {}
for appliance_name, appliance_results in out_appliance.iteritems():
    output[appliance_name] = pd.Series(appliance_results[0])
    tot = len(appliance_results)
    for i in range(1, tot):
        output[appliance_name] = output[appliance_name] + pd.Series(appliance_results[i])

output_df = pd.DataFrame(output)
output_df = output_df.div(tot)

# %%
#output_df.to_csv("sensitivity_num_homes.csv")
output_df = pd.read_csv("sensitivity_num_homes.csv", index_col=0)

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from common_functions import latexify, format_axes

# %%
latexify()
# Out:
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: axes.color_cycle is deprecated and replaced with axes.prop_cycle; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))
# /Users/nipunbatra/anaconda/lib/python2.7/site-packages/matplotlib/__init__.py:872: UserWarning: text.fontsize is deprecated and replaced with font.size; please use the latter.
#   warnings.warn(self.msg_depr % (key, alt_key))

# %%
tableau20blind =  [(31, 119, 180), (174, 199, 232), (255, 127, 14), (255, 187, 120),  
             (44, 160, 44), (152, 223, 138), (214, 39, 40), (255, 152, 150),  
             (148, 103, 189), (197, 176, 213), (140, 86, 75), (196, 156, 148),  
             (227, 119, 194), (247, 182, 210), (127, 127, 127), (199, 199, 199),  
             (188, 189, 34), (219, 219, 141), (23, 190, 207), (158, 218, 229)]
  
# Rescale to values between 0 and 1
for i in range(len(tableau20blind)):  
    r, g, b = tableau20blind[i]  
    tableau20blind[i] = (r / 255., g / 255., b / 255.)
    
markers = ['o','^','*','v','.','d']

# %%
appliance_name_mapping = {"dr": "Dryer", "wm": "Washing machine",
                          "fridge":"Fridge","light":"Lighting",
                          "hvac":"HVAC","dw":"Dish washer"}

normalised_output = {}
fig, ax = plt.subplots(1,1)
for i, appliance_name in enumerate(output_df.columns):
    temp = output_df[appliance_name].dropna()
    temp.index= np.linspace(0, 1, len(output_df[appliance_name].dropna()))
    normalised_output[appliance_name] = temp
    pd.Series(normalised_output[appliance_name]).plot(ax=ax, label=appliance_name_mapping[appliance_name], 
                                                      color=tableau20blind[i*2])
plt.xlim((0.1,1.))
plt.ylim((0, 100))
plt.legend(loc='center left', bbox_to_anchor=(0, 1.1), ncol=2)
plt.xlabel("Proportion of homes in traning set")
plt.ylabel("Accuracy")
format_axes(plt.gca())
plt.tight_layout()
plt.savefig("/Users/nipunbatra/git/monthly-disaggregation/results/sensitivity_num_homes.png",bbox_inches="tight")
plt.savefig("/Users/nipunbatra/git/monthly-disaggregation/results/sensitivity_num_homes.pdf",bbox_inches="tight")

# %%
normalised_output_df = pd.DataFrame(normalised_output)
