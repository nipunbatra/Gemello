# %%
from multipledispatch import dispatch

# %%
@dispatch(int, int)
def add(a, b, **kwargs):
    print kwargs
    print a+b

@dispatch(object, object)
def add(a, b, **kwargs):
    print kwargs
    print str(a) + str(b)

# %%
add(2, 3)
# Out:
# {}
# 5

# %%
add('2','3')
# Out:
# {}
# 23
