# %%
import pandas as pd

# %%
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
cross = pd.read_clipboard()

# %%
cross
# Out:
#       fridge      hvac        wm
# 5   64.76362  66.32757  62.95134
# 10  66.20989  65.20457  45.53760
# 15  67.88528  69.56604  53.56077
# 20  69.07886  68.88634  50.00012
# 25  69.34046  71.61025  50.05390
# 30  74.96292  68.49976  51.01762
# 35  73.07813  70.92961  54.57937
# 40  71.35425  64.52414  47.74155
# 45       NaN       NaN       NaN

# %%
cross.plot()

# %%
same = pd.read_clipboard()

# %%
same.plot()

# %%
for appliance in same.columns:
    df = pd.DataFrame({"Same":same[appliance],"Cross":cross[appliance]})
    df.plot(title=appliance)
    plt.savefig("../results/cross-sd-austin-numhomes-"+appliance+".png")
